# %%
from pass_hulls import plot_pass_hulls
import matplotlib.pyplot as plt

fig = plot_pass_hulls(
    csv_path='data/ESP-La Liga/2024-25/ATHBAR_20240824/2_passes_complete.csv',
    home_logo_path='images/athletic.png',
    away_logo_path='images/barcelona.png',
    season='2024-2025'
)
plt.show()
# Out:
# /home/oriol/FD/data/viz/pass_hulls.py:269: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
