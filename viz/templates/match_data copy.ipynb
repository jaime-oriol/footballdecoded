# %%
import sys
sys.path.append('..')
from viz.match_data import extract_match_complete

# %%
# Athletic Club vs Barcelona - 24/08/2024
# IDS DE PARTIDO
WS_ID = 1913918       # WhoScored match ID
US_ID = 29160         # Understat match ID

# INFORMACIÓN DEL PARTIDO
LEAGUE = 'ESP-La Liga'     # Liga
SEASON = '2025-26'         # Temporada
HOME_TEAM = 'Mallorca'  # Equipo local
AWAY_TEAM = 'Barcelona'    # Equipo visitante
MATCH_DATE = '2025-08-16'  # Fecha del partido

# %%
result = extract_match_complete(
    ws_id=WS_ID,
    us_id=US_ID, 
    league=LEAGUE,
    season=SEASON,
    home_team=HOME_TEAM,
    away_team=AWAY_TEAM,
    match_date=MATCH_DATE
)
# Out:
# Extracting: Athletic Club vs Barcelona (2024-08-24)
# --------------------------------------------------
# INFO     Retrieving calendar for ESP-La Liga 2425
# INFO     [1/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [2/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [3/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [4/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [5/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [6/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [7/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [8/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [9/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [10/10] Retrieving fixtures for ESP-La Liga 2425
# INFO     [1/1] Retrieving game with id=1821769
# 1. match_events.csv: 1810 events
# 2. player_network.csv: 258 records
# 3. match_aggregates.csv: 68 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 90 info records
#
# ...
