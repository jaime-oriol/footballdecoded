# %%
import os
from viz.pass_analysis import plot_pass_flow, plot_pass_hull

# %%
EVENTS_CSV = '../data/match_events.csv'
INFO_CSV = '../data/match_info.csv'
AGGREGATES_CSV = '../data/match_aggregates.csv'
HOME_LOGO = '../../blog/logos/LaLiga/Athletic Bilbao.png'
AWAY_LOGO = '../../blog/logos/LaLiga/FC Barcelona.png'

# %%
fig_flow = plot_pass_flow(
    events_csv_path=EVENTS_CSV,
    info_csv_path=INFO_CSV,
    home_colors=['#FF6347', '#FFFFFF'], 
    away_colors=['#00BFFF', '#8B0000'],
    home_logo_path=HOME_LOGO,
    away_logo_path=AWAY_LOGO
)

fig_hull = plot_pass_hull(
    events_csv_path=EVENTS_CSV,
    info_csv_path=INFO_CSV,
    aggregates_csv_path=AGGREGATES_CSV,
    home_colors=['#FF6347', '#FFFFFF'], 
    away_colors=['#00BFFF', '#8B0000'],
    home_logo_path=HOME_LOGO,
    away_logo_path=AWAY_LOGO
)
