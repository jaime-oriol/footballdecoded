# %%
from viz.pass_network import plot_pass_network
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
fig = plot_pass_network(
    network_csv_path='../data/player_network.csv',  
    info_csv_path='../data/match_info.csv',
    home_logo_path='../../blog/logos/LaLiga/Athletic Bilbao.png',
    away_logo_path='../../blog/logos/LaLiga/FC Barcelona.png'
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig = plot_pass_network(
#       2     network_csv_path='../data/player_network.csv',
#       3     info_csv_path='../data/match_info.csv',
#       4     home_logo_path='../../blog/logos/LaLiga/Athletic Bilbao.png',
#       5     away_logo_path='../../blog/logos/LaLiga/FC Barcelona.png'
#       6 )
#
# File ~/FD/data/viz/pass_network.py:30, in plot_pass_network(network_csv_path, info_csv_path, home_logo_path, away_logo_path, figsize, save_path)
#      27 season = info_df[info_df['info_key'] == 'season']['info_value'].iloc[0]
#      29 # Extraer resultado
# ---> 30 home_goals = int(info_df[(info_df['info_key'] == 'goals') & (info_df['team'] == home_team)]['numeric_value'].iloc[0])
#      31 away_goals = int(info_df[(info_df['info_key'] == 'goals') & (info_df['team'] == away_team)]['numeric_value'].iloc[0])
#      33 positions_df = network_df[network_df['record_type'] == 'position'].copy()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1656, in _iLocIndexer._getitem_axis(self, key, axis)
#    1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
# -> 1656 self._validate_integer(key, axis)
#    1658 return self.obj._ixs(key, axis=axis)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
