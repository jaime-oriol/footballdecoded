# %%
from viz.pass_network import plot_pass_network
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
fig = plot_pass_network(
    network_csv_path='../data/player_network.csv',
    aggregates_csv_path='../data/match_aggregates.csv', 
    info_csv_path='../data/match_info.csv',
    home_logo_path='../../blog/logos/LaLiga/Athletic Bilbao.png',
    away_logo_path='../../blog/logos/LaLiga/FC Barcelona.png'
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_actions'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig = plot_pass_network(
#       2     network_csv_path='../data/player_network.csv',
#       3     aggregates_csv_path='../data/match_aggregates.csv',
#       4     info_csv_path='../data/match_info.csv',
#       5     home_logo_path='../../blog/logos/LaLiga/Athletic Bilbao.png',
#       6     away_logo_path='../../blog/logos/LaLiga/FC Barcelona.png'
#       7 )
#
# File ~/FD/data/viz/pass_network.py:194, in plot_pass_network(network_csv_path, aggregates_csv_path, info_csv_path, home_logo_path, away_logo_path, figsize, save_path)
#     191 pitch.draw(ax=ax)
#     193 # Procesar datos del equipo
# --> 194 team_players, team_connections = process_team_data(team)
#     196 if team_players.empty:
#     197     ax.text(52.5, 35, f"No data for {team}", ha='center', va='center',
#     198            fontsize=16, color='white', fontweight='bold')
#
# File ~/FD/data/viz/pass_network.py:136, in plot_pass_network.<locals>.process_team_data(team_name)
#     134 # Rellenar valores faltantes
#     135 team_data['xthreat_total'] = team_data['xthreat_total'].fillna(0)
# --> 136 team_data['total_actions'] = team_data['total_actions'].fillna(1)
#     138 # Calcular tamaños de nodos
#     139 team_data['node_size'] = team_data['total_actions'].apply(calculate_node_size)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'total_actions'
