# %%
import sys
sys.path.append('..')
from viz.match_data import extract_match_complete

# %%
# IDS DE PARTIDO
WS_ID = 0              # WhoScored match ID (ej: 1821769)
US_ID = 0              # Understat match ID (ej: 27353)

# INFORMACIÓN DEL PARTIDO
LEAGUE = ''            # Liga (ej: 'ESP-La Liga')
SEASON = ''            # Temporada (ej: '2024-25')
HOME_TEAM = ''         # Equipo local (ej: 'Athletic Club')
AWAY_TEAM = ''         # Equipo visitante (ej: 'Barcelona')
MATCH_DATE = ''        # Fecha del partido (ej: '2024-08-24')

# %%
result = extract_match_complete(
    ws_id=WS_ID,
    us_id=US_ID, 
    league=LEAGUE,
    season=SEASON,
    home_team=HOME_TEAM,
    away_team=AWAY_TEAM,
    match_date=MATCH_DATE
)
