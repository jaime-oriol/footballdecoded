# %%
import sys
sys.path.append('../../..')
from viz.match_data import extract_match_complete
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
LEAGUE = "ESP-La Liga"
SEASON = "25-26"
TEAM = "Barcelona"
NUM_MATCHES = 14
OUTPUT_DIR = "downloaded_files/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"Configuración:")
print(f"  Liga: {LEAGUE}")
print(f"  Temporada: {SEASON}")
print(f"  Equipo: {TEAM}")
print(f"  Partidos: {NUM_MATCHES}")
# Out:
# Configuración:
#   Liga: ESP-La Liga
#   Temporada: 25-26
#   Equipo: Barcelona
#   Partidos: 14

# %%
match_data = [
    {'date': '2025-08-16 17:30:00', 'home_team': 'Mallorca', 'away_team': 'Barcelona', 'whoscored_id': 1913918, 'understat_id': 29160},
    {'date': '2025-08-23 19:30:00', 'home_team': 'Levante', 'away_team': 'Barcelona', 'whoscored_id': 1913888, 'understat_id': 29171},
    {'date': '2025-08-31 19:30:00', 'home_team': 'Rayo Vallecano', 'away_team': 'Barcelona', 'whoscored_id': 1913904, 'understat_id': 29188},
    {'date': '2025-09-14 19:00:00', 'home_team': 'Barcelona', 'away_team': 'Valencia', 'whoscored_id': 1913922, 'understat_id': 29194},
    {'date': '2025-09-21 19:00:00', 'home_team': 'Barcelona', 'away_team': 'Getafe', 'whoscored_id': 1913903, 'understat_id': 29199},
    {'date': '2025-09-25 19:30:00', 'home_team': 'Real Oviedo', 'away_team': 'Barcelona', 'whoscored_id': 1913936, 'understat_id': 29213},
    {'date': '2025-09-28 16:30:00', 'home_team': 'Barcelona', 'away_team': 'Real Sociedad', 'whoscored_id': 1913949, 'understat_id': 29220},
    {'date': '2025-10-05 14:15:00', 'home_team': 'Sevilla', 'away_team': 'Barcelona', 'whoscored_id': 1913956, 'understat_id': 29233},
    {'date': '2025-10-18 14:15:00', 'home_team': 'Barcelona', 'away_team': 'Girona', 'whoscored_id': 1913969, 'understat_id': 29240},
    {'date': '2025-10-26 15:15:00', 'home_team': 'Real Madrid', 'away_team': 'Barcelona', 'whoscored_id': 1913998, 'understat_id': 29254},
    {'date': '2025-11-02 17:30:00', 'home_team': 'Barcelona', 'away_team': 'Elche', 'whoscored_id': 1913963, 'understat_id': 29260},
    {'date': '2025-11-09 20:00:00', 'home_team': 'Celta Vigo', 'away_team': 'Barcelona', 'whoscored_id': 1913991, 'understat_id': 29274},
    {'date': '2025-11-22 15:15:00', 'home_team': 'Barcelona', 'away_team': 'Athletic Club', 'whoscored_id': 1914008, 'understat_id': 29284},
    {'date': '2025-11-29 15:15:00', 'home_team': 'Barcelona', 'away_team': 'Alaves', 'whoscored_id': 1914018, 'understat_id': 29294}
]

match_ids_14 = pd.DataFrame(match_data)
match_ids_14['date'] = pd.to_datetime(match_ids_14['date'])

print(f"Primeros {NUM_MATCHES} partidos cargados (hardcoded):")
match_ids_14

# %%
print("Scrapers cargados vía extract_match_complete()")

# %%
schedule_df = match_ids_14.copy()

print("Calendario de partidos:\n")
print(schedule_df.to_string(index=True))
print(f"\nTotal: {len(schedule_df)} partidos")

# %%
print("Función extract_match_complete() lista")

# %%
all_match_events = []
all_player_network = []
all_match_aggregates = []
all_spatial_analysis = []
all_match_info = []

print("Iniciando extracción...\n")
print("=" * 70)

for i, row in schedule_df.iterrows():
    print(f"\nPartido {i+1}/{NUM_MATCHES}: {row['home_team']} vs {row['away_team']}")
    
    try:
        result = extract_match_complete(
            ws_id=int(row['whoscored_id']),
            us_id=int(row['understat_id']),
            league=LEAGUE,
            season=SEASON,
            home_team=row['home_team'],
            away_team=row['away_team'],
            match_date=str(row['date'].date())
        )
        
        events = pd.read_csv('../../viz/data/match_events.csv')
        network = pd.read_csv('../../viz/data/player_network.csv')
        aggregates = pd.read_csv('../../viz/data/match_aggregates.csv')
        spatial = pd.read_csv('../../viz/data/spatial_analysis.csv')
        info = pd.read_csv('../../viz/data/match_info.csv')
        
        events['partido_num'] = i + 1
        events['match_id_ws'] = row['whoscored_id']
        events['match_id_us'] = row['understat_id']
        
        network['partido_num'] = i + 1
        network['match_id_ws'] = row['whoscored_id']
        network['match_id_us'] = row['understat_id']
        
        aggregates['partido_num'] = i + 1
        aggregates['match_id_ws'] = row['whoscored_id']
        aggregates['match_id_us'] = row['understat_id']
        
        spatial['partido_num'] = i + 1
        spatial['match_id_ws'] = row['whoscored_id']
        spatial['match_id_us'] = row['understat_id']
        
        info['partido_num'] = i + 1
        info['match_id_ws'] = row['whoscored_id']
        info['match_id_us'] = row['understat_id']
        
        all_match_events.append(events)
        all_player_network.append(network)
        all_match_aggregates.append(aggregates)
        all_spatial_analysis.append(spatial)
        all_match_info.append(info)
        
        print(f"  ✓ Completado")
        
    except Exception as e:
        print(f"  ✗ Error: {str(e)}")
        import traceback
        traceback.print_exc()

print("\n" + "=" * 70)
print(f"Extracción completada: {len(all_match_events)}/{NUM_MATCHES} partidos")

# %%
df_match_events = pd.concat(all_match_events, ignore_index=True) if all_match_events else pd.DataFrame()
df_player_network = pd.concat(all_player_network, ignore_index=True) if all_player_network else pd.DataFrame()
df_match_aggregates = pd.concat(all_match_aggregates, ignore_index=True) if all_match_aggregates else pd.DataFrame()
df_spatial_analysis = pd.concat(all_spatial_analysis, ignore_index=True) if all_spatial_analysis else pd.DataFrame()
df_match_info = pd.concat(all_match_info, ignore_index=True) if all_match_info else pd.DataFrame()

print("Consolidación de datos:")
print(f"  match_events: {len(df_match_events):,} filas")
print(f"  player_network: {len(df_player_network):,} filas")
print(f"  match_aggregates: {len(df_match_aggregates):,} filas")
print(f"  spatial_analysis: {len(df_spatial_analysis):,} filas")
print(f"  match_info: {len(df_match_info):,} filas")

# %%
print("ESTADÍSTICAS")
print("=" * 70)

if not df_match_events.empty:
    print("\nEventos por tipo (top 10):")
    event_counts = df_match_events['event_type'].value_counts().head(10)
    for event_type, count in event_counts.items():
        print(f"  {event_type}: {count:,}")

if not df_match_info.empty and 'xg' in df_match_info.columns:
    total_xg = pd.to_numeric(df_match_info['xg'], errors='coerce').sum()
    print(f"\nxG total acumulado: {total_xg:.2f}")

# %%
base_name = f"{OUTPUT_DIR}barcelona_first14_{SEASON}"

df_match_events.to_csv(f"{base_name}_match_events.csv", index=False, encoding='utf-8')
df_player_network.to_csv(f"{base_name}_player_network.csv", index=False, encoding='utf-8')
df_match_aggregates.to_csv(f"{base_name}_match_aggregates.csv", index=False, encoding='utf-8')
df_spatial_analysis.to_csv(f"{base_name}_spatial_analysis.csv", index=False, encoding='utf-8')
df_match_info.to_csv(f"{base_name}_match_info.csv", index=False, encoding='utf-8')

final_combined = pd.merge(df_match_events, df_match_info, on=['partido_num', 'match_id_ws', 'match_id_us'], how='left')

combined_file = f"{base_name}_COMBINED.csv"
final_combined.to_csv(combined_file, index=False, encoding='utf-8')

print(f"Archivos guardados:")
print(f"  1. {base_name}_match_events.csv ({len(df_match_events):,} filas)")
print(f"  2. {base_name}_player_network.csv ({len(df_player_network):,} filas)")
print(f"  3. {base_name}_match_aggregates.csv ({len(df_match_aggregates):,} filas)")
print(f"  4. {base_name}_spatial_analysis.csv ({len(df_spatial_analysis):,} filas)")
print(f"  5. {base_name}_match_info.csv ({len(df_match_info):,} filas)")
print(f"\n  COMBINADO: {combined_file} ({len(final_combined):,} filas)")

# %%
print("=" * 50)
print("EXTRACCIÓN COMPLETADA")
print("=" * 50)
print(f"Temporada: {SEASON}")
print(f"Equipo: {TEAM}")
print(f"Partidos procesados: {len(all_match_events)}/{NUM_MATCHES}")
print(f"\nArchivo principal:")
print(f"  {combined_file}")
print(f"  {len(final_combined):,} eventos × {len(final_combined.columns)} columnas")
print("=" * 50)
