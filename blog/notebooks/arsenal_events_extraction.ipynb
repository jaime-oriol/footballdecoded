# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../..')))

from blog.get_match_ids import get_match_ids
from viz.match_data import extract_match_complete
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

os.makedirs('../data', exist_ok=True)
print("Setup complete")
# Out:
# Setup complete

# %%
# SEASON 24/25 - Get match IDs
print("="*60)
print("ARSENAL 24/25 - FIRST 11 PREMIER LEAGUE MATCHES")
print("="*60)

matches_2425 = get_match_ids("Arsenal", "ENG-Premier League", "24-25")
matches_2425_first11 = matches_2425.head(11)
matches_2425_first11
# Out:
# ...
# ARSENAL 24/25 - FIRST 11 PREMIER LEAGUE MATCHES
# ...
#
# ...
# Extrayendo IDs de partidos para:
#   Equipo: Arsenal
#   Liga: ENG-Premier League
#   Temporada: 24-25
# ...
#
# Extrayendo de WhoScored...
# INFO     Retrieving calendar for ENG-Premier League 2425
# INFO     [1/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [2/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [3/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [4/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [5/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [6/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [7/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [8/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [9/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [10/10] Retrieving fixtures for ENG-Premier League 2425
#    ✓ Encontrados 38 partidos en WhoScored
#
# Extrayendo de Understat...
# ...

# %%
# Extract complete events 24/25
csv_path_2425 = '../data/arsenal_matches_2425_complete.csv'

if os.path.exists(csv_path_2425):
    print(f"Cargando desde CSV: {csv_path_2425}")
    df_2425 = pd.read_csv(csv_path_2425)
    print(f"Cargados: {len(df_2425)} eventos")
else:
    print("Extrayendo eventos completos 24/25...")
    all_events_2425 = []
    
    for idx, match in matches_2425_first11.iterrows():
        print(f"\n[{idx+1}/11] {match['home_team']} vs {match['away_team']}")
        
        try:
            extract_match_complete(
                ws_id=int(match['whoscored_id']),
                us_id=int(match['understat_id']),
                league=match['league'],
                season=match['season'],
                home_team=match['home_team'],
                away_team=match['away_team'],
                match_date=str(match['date'])
            )
            
            events = pd.read_csv('../../viz/data/match_events.csv')
            
            # Add match context
            is_home = 'Arsenal' in match['home_team']
            events['match_date'] = match['date']
            events['opponent'] = match['away_team'] if is_home else match['home_team']
            events['arsenal_venue'] = 'Home' if is_home else 'Away'
            events['match_id_ws'] = match['whoscored_id']
            events['match_id_us'] = match['understat_id']
            events['match_number'] = idx + 1
            
            all_events_2425.append(events)
            print(f"  {len(events)} eventos totales")
            
        except Exception as e:
            print(f"  Error: {e}")
            continue
    
    if all_events_2425:
        df_2425 = pd.concat(all_events_2425, ignore_index=True)
        df_2425.to_csv(csv_path_2425, index=False)
        print(f"\nGuardado: {csv_path_2425}")
    else:
        df_2425 = pd.DataFrame()

print(f"\nTotal eventos 24/25: {len(df_2425)}")
# Out:
# Extrayendo eventos completos 24/25...
#
# [1/11] Arsenal vs Wolves
#
# Extracting: Arsenal vs Wolves (2024-08-17 14:00:00)
# --------------------------------------------------
# INFO     Retrieving calendar for ENG-Premier League 2425
# INFO     [1/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [2/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [3/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [4/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [5/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [6/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [7/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [8/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [9/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [10/10] Retrieving fixtures for ENG-Premier League 2425
# INFO     [1/1] Retrieving game with id=1821052
# 1. match_events.csv: 1750 events
# ...

# %%
# SEASON 25/26 - Get match IDs
print("="*60)
print("ARSENAL 25/26 - FIRST 11 PREMIER LEAGUE MATCHES")
print("="*60)

matches_2526 = get_match_ids("Arsenal", "ENG-Premier League", "25-26")
matches_2526_first11 = matches_2526.head(11)
matches_2526_first11
# Out:
# ...
# ARSENAL 25/26 - FIRST 11 PREMIER LEAGUE MATCHES
# ...
#
# ...
# Extrayendo IDs de partidos para:
#   Equipo: Arsenal
#   Liga: ENG-Premier League
#   Temporada: 25-26
# ...
#
# Extrayendo de WhoScored...
# INFO     Retrieving calendar for ENG-Premier League 2526
# INFO     [1/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [2/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [3/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [4/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [5/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [6/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [7/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [8/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [9/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [10/10] Retrieving fixtures for ENG-Premier League 2526
#    ✓ Encontrados 38 partidos en WhoScored
#
# Extrayendo de Understat...
# ...

# %%
# Extract complete events 25/26
csv_path_2526 = '../data/arsenal_matches_2526_complete.csv'

if os.path.exists(csv_path_2526):
    print(f"Cargando desde CSV: {csv_path_2526}")
    df_2526 = pd.read_csv(csv_path_2526)
    print(f"Cargados: {len(df_2526)} eventos")
else:
    print("Extrayendo eventos completos 25/26...")
    all_events_2526 = []
    
    for idx, match in matches_2526_first11.iterrows():
        print(f"\n[{idx+1}/11] {match['home_team']} vs {match['away_team']}")
        
        try:
            extract_match_complete(
                ws_id=int(match['whoscored_id']),
                us_id=int(match['understat_id']),
                league=match['league'],
                season=match['season'],
                home_team=match['home_team'],
                away_team=match['away_team'],
                match_date=str(match['date'])
            )
            
            events = pd.read_csv('../../viz/data/match_events.csv')
            
            # Add match context
            is_home = 'Arsenal' in match['home_team']
            events['match_date'] = match['date']
            events['opponent'] = match['away_team'] if is_home else match['home_team']
            events['arsenal_venue'] = 'Home' if is_home else 'Away'
            events['match_id_ws'] = match['whoscored_id']
            events['match_id_us'] = match['understat_id']
            events['match_number'] = idx + 1
            
            all_events_2526.append(events)
            print(f"  {len(events)} eventos totales")
            
        except Exception as e:
            print(f"  Error: {e}")
            continue
    
    if all_events_2526:
        df_2526 = pd.concat(all_events_2526, ignore_index=True)
        df_2526.to_csv(csv_path_2526, index=False)
        print(f"\nGuardado: {csv_path_2526}")
    else:
        df_2526 = pd.DataFrame()

print(f"\nTotal eventos 25/26: {len(df_2526)}")
# Out:
# Extrayendo eventos completos 25/26...
#
# [1/11] Manchester United vs Arsenal
#
# Extracting: Manchester United vs Arsenal (2025-08-17 15:30:00)
# --------------------------------------------------
# INFO     Retrieving calendar for ENG-Premier League 2526
# INFO     [1/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [2/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [3/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [4/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [5/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [6/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [7/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [8/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [9/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [10/10] Retrieving fixtures for ENG-Premier League 2526
# INFO     [1/1] Retrieving game with id=1903125
# ...

# %%
# Summary
print("="*60)
print("EXTRACTION COMPLETE")
print("="*60)

for name, df, path in [('24/25', df_2425, csv_path_2425), ('25/26', df_2526, csv_path_2526)]:
    if len(df) > 0:
        shots = df[df['event_type'].str.contains('Shot|Goal', case=False, na=False)]
        print(f"\n{name}: {path}")
        print(f"  Eventos totales: {len(df)}")
        print(f"  Partidos: {df['match_number'].nunique()}")
        print(f"  Tiros: {len(shots)}")
        print(f"  xG total: {shots['xg'].sum():.2f}")
        print(f"  Columnas: {len(df.columns)}")
# Out:
# ...
# EXTRACTION COMPLETE
# ...
#
# 24/25: ../data/arsenal_matches_2425_complete.csv
#   Eventos totales: 19610
#   Partidos: 11
#   Tiros: 304
#   xG total: 33.16
#   Columnas: 61
#
# 25/26: ../data/arsenal_matches_2526_complete.csv
#   Eventos totales: 16056
#   Partidos: 9
#   Tiros: 203
#   xG total: 21.16
#   Columnas: 61
