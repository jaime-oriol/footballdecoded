# %%
# Imports necesarios
import sys
sys.path.append('../../..')
from viz.stats_table import create_goalkeeper_analysis
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
donnarumma = [
    ("1st Leg Key Stats", ""),
    ("Saves", "5"),
    ("Goals conceded", "0"),
    ("xGOT faced", "1.23"),
    ("Goals prevented", "1.23"),
    ("2nd Leg Key Stats", ""),
    ("Saves", "3"),
    ("Goals conceded", "1"),
    ("xGOT faced", "1.86"),
    ("Goals prevented", "0.86"),
]

# Crear análisis de portero
fig_donnarumma = create_goalkeeper_analysis(
    player_name='Donnarumma',
    team_name='vs Arsenal semi-final UCL',
    enriched_metrics=donnarumma,
    player_image_path='../../caras/extras/Donnarumma.png'
)

# %%
raya = [
    ("1st Leg Key Stats", ""),
    ("Saves", "3"),
    ("Goals conceded", "1"),
    ("xGOT faced", "1.04"),
    ("Goals prevented", "0.04"),
    ("2nd Leg Key Stats", ""),
    ("Saves", "4"),
    ("Goals conceded", "2"),
    ("xGOT faced", "3.56"),
    ("Goals prevented", "1.56"),
]

# Crear análisis de portero
fig_raya = create_goalkeeper_analysis(
    player_name='David Raya',
    team_name='vs PSG semi-final UCL',
    enriched_metrics=raya,
    player_image_path='../../caras/extras/Raya.png'
)

# %%
szczesny = [
    ("1st Leg Key Stats", ""),
    ("Saves", "0"),
    ("Goals conceded", "3"),
    ("xGOT faced", "1.98"),
    ("Goals prevented", "-1.02"),
    ("2nd Leg Key Stats", ""),
    ("Saves", "3"),
    ("Goals conceded", "4"),
    ("xGOT faced", "4.19"),
    ("Goals prevented", "0.19"),
]

# Crear análisis de portero
fig_szczesny = create_goalkeeper_analysis(
    player_name='Szczesny',
    team_name='vs Inter semi-final UCL',
    enriched_metrics=szczesny,
    player_image_path='../../caras/extras/Szczesny.png'
)

# %%
sommer = [
    ("1st Leg Key Stats", ""),
    ("Saves", "7"),
    ("Goals conceded", "3"),
    ("xGOT faced", "2.77"),
    ("Goals prevented", "0.77"),
    ("2nd Leg Key Stats", ""),
    ("Saves", "7"),
    ("Goals conceded", "3"),
    ("xGOT faced", "3.97"),
    ("Goals prevented", "0.97"),
]

# Crear análisis de portero
fig_sommer = create_goalkeeper_analysis(
    player_name='Yann Sommer',
    team_name='vs Barça semi-final UCL',
    enriched_metrics=sommer,
    player_image_path='../../caras/extras/Sommer.png'
)
