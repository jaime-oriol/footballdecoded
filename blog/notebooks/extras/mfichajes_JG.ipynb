# %%
donnarumma = [
    ("1st Leg", ""),
    ("Saves", "5"),
    ("Goals conceded", "0"),
    ("xGOT faced", "1.23"),
    ("Goals prevented", "1.23"),
    ("2nd Leg", ""),
    ("Saves", "3"),
    ("Goals conceded", "1"),
    ("xGOT faced", "1.86"),
    ("Goals prevented", "0.86"),
]

# Crear análisis completo
fig_rafa = create_player_analysis_complete(
    player_name='Donnarumma',
    team_name='vs Arsenal Semis UCL',
    enriched_metrics=donnarumma,
    events_df=events,
    player_image_path='../../caras/villareal/Marin.png'
)

# %%
raya = [
    ("1st Leg", ""),
    ("Saves", "3"),
    ("Goals conceded", "1"),
    ("xGOT faced", "1.04"),
    ("Goals prevented", "0.04"),
    ("2nd Leg", ""),
    ("Saves", "4"),
    ("Goals conceded", "2"),
    ("xGOT faced", "3.56"),
    ("Goals prevented", "1.56"),
]

# Crear análisis completo
fig_rafa = create_player_analysis_complete(
    player_name='David Raya',
    team_name='vs PSG Semis UCL',
    enriched_metrics=donnaruma,
    events_df=events,
    player_image_path='../../caras/villareal/Marin.png'
)

# %%
szczesny = [
    ("1st Leg", ""),
    ("Saves", "0"),
    ("Goals conceded", "3"),
    ("xGOT faced", "1.98"),
    ("Goals prevented", "-1.02"),
    ("2nd Leg", ""),
    ("Saves", "3"),
    ("Goals conceded", "4"),
    ("xGOT faced", "4.19"),
    ("Goals prevented", "0.19"),
]

# Crear análisis completo
fig_rafa = create_player_analysis_complete(
    player_name='Szczesny',
    team_name='vs Inter Semis UCL',
    enriched_metrics=szczesny,
    events_df=events,
    player_image_path='../../caras/villareal/Marin.png'
)

# %%
sommer = [
    ("1st Leg", ""),
    ("Saves", "7"),
    ("Goals conceded", "3"),
    ("xGOT faced", "2.77"),
    ("Goals prevented", "0.77"),
    ("2nd Leg", ""),
    ("Saves", "7"),
    ("Goals conceded", "3"),
    ("xGOT faced", "3.97"),
    ("Goals prevented", "0.97"),
]

# Crear análisis completo
fig_rafa = create_player_analysis_complete(
    player_name='Yann Sommer',
    team_name='vs Barça Semis UCL',
    enriched_metrics=sommer,
    events_df=events,
    player_image_path='../../caras/villareal/Marin.png'
)
