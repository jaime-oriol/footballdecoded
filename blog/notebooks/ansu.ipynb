# %% [markdown]
# # Player Event Analysis

# %%
# PARAMETROS
PLAYER_NAME = "Ansu Fati"
PLAYER_SEARCH = "Ansu|Fati"
TEAM_NAME = "Monaco"
CSV_FILE = "../data/monaco_25-26.csv"
SEASON = "25-26"
OUTPUT_FILE = f"../data/{PLAYER_NAME.lower().replace(' ', '_')}_all_events_{SEASON}.csv"

# %%
# STEP 2: Load match list
import sys
sys.path.append('../..')
from viz.match_data import extract_match_complete
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

matches_df = pd.read_csv(CSV_FILE)
print(f"Total partidos: {len(matches_df)}")
matches_df.head()
# Out:
# Total partidos: 9
#          date home_team   away_team  whoscored_id  understat_id       league  \
# 0  2025-08-17    Monaco        Nice       1911314       29598.0  FRA-Ligue 1
# 1  2025-08-24   Lorient      Monaco       1911376       29585.0  FRA-Ligue 1
# 2  2025-08-31    Monaco        Metz       1911366       29580.0  FRA-Ligue 1
# 3  2025-09-14   Auxerre      Monaco       1911330       29565.0  FRA-Ligue 1
# 4  2025-09-21    Monaco  Strasbourg       1911318       29563.0  FRA-Ligue 1
#
#   season
# 0  25-26
# 1  25-26
# 2  25-26
# 3  25-26
# 4  25-26

# %%
# STEP 3: Process all matches and extract player events
all_player_events = []

for idx, match in matches_df.iterrows():
    print(f"\n[{idx+1}/{len(matches_df)}] {match['home_team']} vs {match['away_team']}")
    
    try:
        extract_match_complete(
            ws_id=int(match['whoscored_id']),
            us_id=int(match['understat_id']),
            league=match['league'],
            season=match['season'],
            home_team=match['home_team'],
            away_team=match['away_team'],
            match_date=match['date']
        )
        
        events = pd.read_csv('../../viz/data/match_events.csv')
        player_events = events[events['player'].str.contains(PLAYER_SEARCH, case=False, na=False)].copy()
        
        if len(player_events) > 0:
            is_home = TEAM_NAME.lower() in match['home_team'].lower()
            is_away = TEAM_NAME.lower() in match['away_team'].lower()
            
            if is_home:
                player_events['venue'] = 'Home'
                player_events['opponent'] = match['away_team']
            elif is_away:
                player_events['venue'] = 'Away'
                player_events['opponent'] = match['home_team']
            else:
                print(f"  WARN: {TEAM_NAME} no encontrado en ningún equipo")
                continue
            
            player_events['match_date'] = match['date']
            player_events['match_id_ws'] = match['whoscored_id']
            player_events['match_id_us'] = match['understat_id']
            all_player_events.append(player_events)
            print(f"  {len(player_events)} eventos {PLAYER_NAME}")
        else:
            print(f"  Sin eventos {PLAYER_NAME}")
            
    except Exception as e:
        print(f"  Error: {e}")
        continue

print(f"\nPartidos con eventos {PLAYER_NAME}: {len(all_player_events)}")
# Out:
# [1/9] Monaco vs Nice
#
# Extracting: Monaco vs Nice (2025-08-17)
# --------------------------------------------------
# INFO     Retrieving calendar for FRA-Ligue 1 2526
# INFO     [1/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [2/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [3/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [4/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [5/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [6/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [7/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [8/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [9/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [10/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [1/1] Retrieving game with id=1911314
# 1. match_events.csv: 1819 events
# 2. player_network.csv: 254 records
# 3. match_aggregates.csv: 67 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 91 info records
#
# Shots: 29 | Goals: 4 | xG: 3.59
#   79 eventos Ansu Fati
#
# [2/9] Lorient vs Monaco
#
# Extracting: Lorient vs Monaco (2025-08-24)
# --------------------------------------------------
# INFO     Retrieving calendar for FRA-Ligue 1 2526
# INFO     [1/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [2/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [3/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [4/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [5/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [6/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [7/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [8/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [9/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [10/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [1/1] Retrieving game with id=1911376
# 1. match_events.csv: 2092 events
# 2. player_network.csv: 299 records
# 3. match_aggregates.csv: 68 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 95 info records
#
# Shots: 24 | Goals: 4 | xG: 3.07
#   32 eventos Ansu Fati
#
# [3/9] Monaco vs Metz
#
# Extracting: Monaco vs Metz (2025-08-31)
# --------------------------------------------------
# INFO     Retrieving calendar for FRA-Ligue 1 2526
# INFO     [1/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [2/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [3/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [4/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [5/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [6/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [7/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [8/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [9/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [10/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [1/1] Retrieving game with id=1911366
# 1. match_events.csv: 1901 events
# 2. player_network.csv: 274 records
# 3. match_aggregates.csv: 67 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 91 info records
#
# Shots: 25 | Goals: 7 | xG: 5.64
#   41 eventos Ansu Fati
#
# [4/9] Auxerre vs Monaco
#
# Extracting: Auxerre vs Monaco (2025-09-14)
# --------------------------------------------------
# INFO     Retrieving calendar for FRA-Ligue 1 2526
# INFO     [1/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [2/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [3/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [4/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [5/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [6/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [7/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [8/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [9/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [10/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [1/1] Retrieving game with id=1911330
# 1. match_events.csv: 1902 events
# 2. player_network.csv: 237 records
# 3. match_aggregates.csv: 66 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 92 info records
#
# Shots: 23 | Goals: 3 | xG: 2.53
#   Sin eventos Ansu Fati
#
# [5/9] Monaco vs Strasbourg
#
# Extracting: Monaco vs Strasbourg (2025-09-21)
# --------------------------------------------------
# INFO     Retrieving calendar for FRA-Ligue 1 2526
# INFO     [1/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [2/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [3/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [4/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [5/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [6/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [7/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [8/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [9/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [10/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [1/1] Retrieving game with id=1911318
# 1. match_events.csv: 1924 events
# 2. player_network.csv: 280 records
# 3. match_aggregates.csv: 68 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 95 info records
#
# Shots: 24 | Goals: 5 | xG: 4.13
#   Sin eventos Ansu Fati
#
# [6/9] Lille vs Monaco
#
# Extracting: Lille vs Monaco (2025-09-28)
# --------------------------------------------------
# INFO     Retrieving calendar for FRA-Ligue 1 2526
# INFO     [1/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [2/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [3/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [4/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [5/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [6/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [7/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [8/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [9/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [10/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [1/1] Retrieving game with id=1911279
# 1. match_events.csv: 1821 events
# 2. player_network.csv: 247 records
# 3. match_aggregates.csv: 64 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 79 info records
#
# Shots: 24 | Goals: 1 | xG: 3.93
#   Sin eventos Ansu Fati
#
# [7/9] Monaco vs Le Havre
#
# Extracting: Monaco vs Le Havre (2025-10-05)
# --------------------------------------------------
# INFO     Retrieving calendar for FRA-Ligue 1 2526
# INFO     [1/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [2/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [3/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [4/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [5/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [6/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [7/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [8/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [9/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [10/10] Retrieving fixtures for FRA-Ligue 1 2526
# INFO     [1/1] Retrieving game with id=1911290
# 1. match_events.csv: 1944 events
# 2. player_network.csv: 257 records
# 3. match_aggregates.csv: 68 records
# 4. spatial_analysis.csv: 50 spatial records
# 5. match_info.csv: 91 info records
#
# Shots: 23 | Goals: 4 | xG: 2.35
#   Sin eventos Ansu Fati
#
# [8/9] Club Brugge vs Monaco
#   Error: cannot convert float NaN to integer
#
# [9/9] Monaco vs Manchester City
#   Error: cannot convert float NaN to integer
#
# Partidos con eventos Ansu Fati: 3

# %%
# STEP 4: Concatenate and save all player events
if len(all_player_events) > 0:
    df = pd.concat(all_player_events, ignore_index=True)
    df = df.sort_values('match_date').reset_index(drop=True)
    
    df.to_csv(OUTPUT_FILE, index=False)
    
    print(f"Guardado: {OUTPUT_FILE}")
    print(f"Total eventos: {len(df)}")
    display(df[['match_date', 'opponent', 'venue', 'minute', 'type', 'player']].head(15))
else:
    print(f"Sin eventos {PLAYER_NAME}")
# Out:
# Guardado: ../data/ansu_fati_all_events_25-26.csv
# Total eventos: 152
#     match_date opponent venue  minute       type     player
# 0   2025-08-17     Nice  Home     2.0       Pass  Ansu Fati
# 1   2025-08-17     Nice  Home    79.0  BallTouch  Ansu Fati
# 2   2025-08-17     Nice  Home    79.0     TakeOn  Ansu Fati
# 3   2025-08-17     Nice  Home    79.0     TakeOn  Ansu Fati
# 4   2025-08-17     Nice  Home    78.0       Pass  Ansu Fati
# 5   2025-08-17     Nice  Home    77.0      Carry  Ansu Fati
# 6   2025-08-17     Nice  Home    77.0       Pass  Ansu Fati
# 7   2025-08-17     Nice  Home    76.0       Pass  Ansu Fati
# 8   2025-08-17     Nice  Home    81.0       Pass  Ansu Fati
# 9   2025-08-17     Nice  Home    74.0      Carry  Ansu Fati
# 10  2025-08-17     Nice  Home    74.0      Carry  Ansu Fati
# 11  2025-08-17     Nice  Home    74.0       Pass  Ansu Fati
# 12  2025-08-17     Nice  Home    71.0       Pass  Ansu Fati
# 13  2025-08-17     Nice  Home    69.0       Pass  Ansu Fati
# 14  2025-08-17     Nice  Home    66.0      Carry  Ansu Fati

# %%
# STEP 5: Generate statistics
if len(all_player_events) > 0:
    print(f"ESTADISTICAS {PLAYER_NAME.upper()} - {TEAM_NAME.upper()} {SEASON}")
    print("="*60)
    
    total = len(df)
    partidos = df['match_date'].nunique()
    
    print(f"\nGENERAL:")
    print(f"  Partidos: {partidos}")
    print(f"  Total eventos: {total}")
    print(f"  Eventos/partido: {total/partidos:.1f}")
    
    print(f"\nTIPOS DE EVENTOS:")
    tipos = df['type'].value_counts().head(10)
    for tipo, count in tipos.items():
        pct = (count/total*100)
        print(f"  {tipo}: {count} ({pct:.1f}%)")
    
    print(f"\nHOME vs AWAY:")
    venue_stats = df.groupby('venue').agg({'player': 'count', 'match_date': 'nunique'}).rename(columns={'player': 'eventos', 'match_date': 'partidos'})
    print(venue_stats)
    
    print(f"\nTOP 10 PARTIDOS (más eventos):")
    top_matches = df.groupby(['match_date', 'opponent']).size().sort_values(ascending=False).head(10)
    for (fecha, rival), eventos in top_matches.items():
        print(f"  {fecha[:10]} vs {rival}: {eventos} eventos")
# Out:
# ESTADISTICAS ANSU FATI - MONACO 25-26
# ============================================================
#
# GENERAL:
#   Partidos: 3
#   Total eventos: 152
#   Eventos/partido: 50.7
#
# TIPOS DE EVENTOS:
#   Pass: 78 (51.3%)
#   Carry: 35 (23.0%)
#   TakeOn: 6 (3.9%)
#   Aerial: 6 (3.9%)
#   BallRecovery: 5 (3.3%)
#   Goal: 5 (3.3%)
#   Tackle: 4 (2.6%)
#   BallTouch: 3 (2.0%)
#   BlockedPass: 2 (1.3%)
#   MissedShots: 2 (1.3%)
#
# HOME vs AWAY:
#        eventos  partidos
# venue
# Away        32         1
# Home       120         2
#
# TOP 10 PARTIDOS (más eventos):
#   2025-08-17 vs Nice: 79 eventos
#   2025-08-31 vs Metz: 41 eventos
#   2025-08-24 vs Lorient: 32 eventos
