# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from PIL import Image
import os
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../..')
from database.connection import get_db_manager
from viz.scatter import create_diamond_scatter

# %%
BACKGROUND_COLOR = '#313332'
FONT_FAMILY = 'DejaVu Sans'

node_cmap = mcolors.LinearSegmentedColormap.from_list("", [
    'deepskyblue', 'cyan', 'lawngreen', 'yellow', 
    'gold', 'lightpink', 'tomato'
])

os.makedirs('figures', exist_ok=True)

# %%
db = get_db_manager()

query = """
SELECT 
    unique_player_id,
    player_name,
    team,
    league,
    season,
    position,
    fbref_metrics,
    understat_metrics
FROM footballdecoded.players_domestic p
WHERE p.season = '2425'
    AND p.league = 'ESP-La Liga'
ORDER BY p.team, p.player_name
"""

df_raw = pd.read_sql(query, db.engine)
db.close()

print(f"Extracted: {df_raw.shape[0]} records")
# Out:
# 2025-09-22 18:57:15,472 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2025-09-22 18:57:16,091 - database.connection - INFO - Database connection successful
# Extracted: 588 records

# %%
# Filtrar por minutos mínimos PRIMERO (como en mika.ipynb)
df_filtered = df_raw[
    df_raw['fbref_metrics'].apply(
        lambda x: x.get('minutes_played', 0) if x else 0
    ) >= 600
].copy()

print(f"Filtro 600+ min: {df_filtered.shape[0]} jugadores")

# NUEVO: Filtrar por posición GK ANTES de calcular percentiles
df_filtered = df_filtered[df_filtered['position'].str.contains('GK', na=False)].copy()
print(f"Filtro GK: {df_filtered.shape[0]} porteros")

# Funciones de extracción (como en mika.ipynb)
def extract_metrics(df, col_name):
    result = pd.DataFrame(index=df.index)
    
    all_keys = set()
    for _, row in df.iterrows():
        if isinstance(row[col_name], dict):
            all_keys.update(row[col_name].keys())
    
    for key in all_keys:
        values = []
        for _, row in df.iterrows():
            if isinstance(row[col_name], dict) and key in row[col_name]:
                raw_value = row[col_name][key]
                converted_value = _convert_to_float(raw_value)
                values.append(converted_value)
            else:
                values.append(np.nan)
        
        valid_count = pd.Series(values).notna().sum()
        if valid_count >= 5:
            result[key] = values
    
    return result

def _convert_to_float(value):
    if isinstance(value, (int, float)):
        return float(value)
    
    if value is None or pd.isna(value):
        return np.nan
    
    if isinstance(value, str):
        if value.strip() == '':
            return np.nan
        
        if value.lower().strip() in ['nan', 'none', 'null', '-']:
            return np.nan
        
        try:
            return float(value)
        except (ValueError, TypeError):
            return np.nan
    
    return np.nan

# Extraer métricas numéricas
fbref_nums = extract_metrics(df_filtered, 'fbref_metrics')
understat_nums = extract_metrics(df_filtered, 'understat_metrics')
print(f"FBref: {fbref_nums.shape[1]} métricas | Understat: {understat_nums.shape[1]} métricas")
# Out:
# Filtro 600+ min: 399 jugadores
# Filtro GK: 29 porteros
# FBref: 179 métricas | Understat: 8 métricas

# %%
# Métricas a excluir de per90 (como en mika.ipynb)
exclude_per90 = {
    'pass_completion_pct', 'shots_on_target_pct', 'Take-Ons_Succ%', 'Take-Ons_Tkld%', 
    'Aerial Duels_Won%', 'Challenges_Tkl%', 'Save%', 'Launched_Cmp%', 'Crosses_Stp%',
    'shots_per_90', 'GA90', 'GCA_GCA90', 'SCA_SCA90', 'Team Success_+/-90', 'SoT/90',
    'npxG/Sh', 'xG+xAG', 'non_penalty_xG_plus_xAG', 'avg_shot_distance', 'minutes_per_match',
    'Passes_AvgLen', 'Goal Kicks_AvgLen', 'Starts_Mn/Start', 'Subs_Mn/Sub', 'Min%',
    'matches_played', 'matches_started', 'minutes_played', 'wins', 'draws', 'losses',
    'understat_buildup_involvement_pct', 'understat_player_id', 'understat_team_id'
}

# Calcular per90 FBref
fbref_per90 = fbref_nums.loc[:, ~fbref_nums.columns.isin(exclude_per90)]
fbref_per90 = (fbref_per90.div(fbref_nums['minutes_played'], axis=0) * 90).round(3)
fbref_per90.columns = [f'{col}_per90' for col in fbref_per90.columns]

# Calcular per90 Understat
understat_per90 = understat_nums.loc[:, ~understat_nums.columns.isin(exclude_per90)]
understat_per90 = (understat_per90.div(fbref_nums['minutes_played'], axis=0) * 90).round(3)
understat_per90.columns = [f'{col}_per90' for col in understat_per90.columns]

print(f"Per90: {fbref_per90.shape[1]} + {understat_per90.shape[1]}")

# COMBINAR todas las métricas
all_metrics = pd.concat([fbref_nums, understat_nums, fbref_per90, understat_per90], axis=1)

# Calcular percentiles (como en mika.ipynb)
all_percentiles = all_metrics.rank(pct=True) * 98 + 1
all_percentiles = all_percentiles.round(0).astype('Int64')
all_percentiles.columns = [f'{col}_pct' for col in all_percentiles.columns]

print(f"Métricas totales: {all_metrics.shape[1]}")
print(f"Percentiles totales: {all_percentiles.shape[1]}")
# Out:
# Per90: 152 + 6
# Métricas totales: 345
# Percentiles totales: 345

# %%
# DataFrame final consolidado (como en mika.ipynb)
base_cols = ['unique_player_id', 'player_name', 'team', 'league', 'season', 'position']

df_final = pd.concat([
    df_filtered[base_cols],
    all_metrics,
    all_percentiles
], axis=1)

print(f"DataFrame final: {df_final.shape[0]} filas, {df_final.shape[1]} columnas")

# Limpieza de Series anidados (como en mika.ipynb)
def clean_series_values(df):
    for col in df.columns:
        series_mask = df[col].apply(lambda x: isinstance(x, pd.Series))
        
        if series_mask.any():
            print(f"Limpiando Series en: {col}")
            df[col] = df[col].apply(
                lambda x: x.iloc[0] if isinstance(x, pd.Series) and not x.empty else x
            )
    return df

df_final = clean_series_values(df_final)

# Eliminar columnas problemáticas
problem_cols = ['shots_on_target_pct']
df_final = df_final.drop(columns=[col for col in problem_cols if col in df_final.columns])

print(f"Limpieza completada: {df_final.shape[1]} columnas finales")

# Usar df_final como df principal
df = df_final.copy()
print(f"DataFrame final: {df.shape[0]} porteros con 600+ minutos")

# PRINT DE TODAS LAS COLUMNAS DISPONIBLES
print("\n" + "="*80)
print("TODAS LAS COLUMNAS DISPONIBLES EN EL DATAFRAME")
print("="*80)

# Separar por tipo de columna
base_columns = [col for col in df.columns if col in base_cols]
fbref_metrics = [col for col in df.columns if col in fbref_nums.columns]
understat_metrics = [col for col in df.columns if col in understat_nums.columns]
per90_metrics = [col for col in df.columns if col.endswith('_per90')]
percentile_metrics = [col for col in df.columns if col.endswith('_pct')]

print(f"\n1. COLUMNAS BASE ({len(base_columns)}):")
for i, col in enumerate(base_columns, 1):
    print(f"   {i:2d}. {col}")

print(f"\n2. MÉTRICAS FBREF ({len(fbref_metrics)}):")
for i, col in enumerate(sorted(fbref_metrics), 1):
    print(f"   {i:3d}. {col}")

print(f"\n3. MÉTRICAS UNDERSTAT ({len(understat_metrics)}):")
for i, col in enumerate(sorted(understat_metrics), 1):
    print(f"   {i:2d}. {col}")

print(f"\n4. MÉTRICAS PER90 ({len(per90_metrics)}):")
for i, col in enumerate(sorted(per90_metrics), 1):
    print(f"   {i:3d}. {col}")

print(f"\n5. PERCENTILES ({len(percentile_metrics)}):")
print("   (Mostrando primeros 20 para evitar spam)")
for i, col in enumerate(sorted(percentile_metrics)[:20], 1):
    print(f"   {i:2d}. {col}")
if len(percentile_metrics) > 20:
    print(f"   ... y {len(percentile_metrics) - 20} más")

print(f"\nRESUMEN TOTAL:")
print(f"- Base: {len(base_columns)}")
print(f"- FBref: {len(fbref_metrics)}")
print(f"- Understat: {len(understat_metrics)}")
print(f"- Per90: {len(per90_metrics)}")
print(f"- Percentiles: {len(percentile_metrics)}")
print(f"- TOTAL: {df.shape[1]} columnas")

print(f"\nPorteros con datos completos: {df.shape[0]} jugadores disponibles")
# Out:
# DataFrame final: 29 filas, 696 columnas
# Limpieza completada: 695 columnas finales
# DataFrame final: 29 porteros con 600+ minutos
#
# ================================================================================
# TODAS LAS COLUMNAS DISPONIBLES EN EL DATAFRAME
# ================================================================================
#
# 1. COLUMNAS BASE (6):
#     1. unique_player_id
#     2. player_name
#     3. team
#     4. league
#     5. season
#     6. position
#
# 2. MÉTRICAS FBREF (179):
#      1. /90
#      2. 2CrdY
#      3. A-xAG
#      4. Aerial Duels_Lost
#      5. Aerial Duels_Won
#      6. Aerial Duels_Won%
#      7. Blocks_Blocks
#      8. Blocks_Pass
#      9. Blocks_Sh
#     10. CS
#     11. CS%
#     12. Carries_1/3
#     13. Carries_CPA
#     14. Carries_Carries
#     15. Carries_Dis
#     16. Carries_Mis
#     17. Carries_PrgC
#     18. Carries_PrgDist
#     19. Carries_TotDist
#     20. Challenges_Att
#     21. Challenges_Lost
#     22. Challenges_Tkl
#     23. Challenges_Tkl%
#     24. Corner Kicks_In
#     25. Corner Kicks_Out
#     26. Corner Kicks_Str
#     27. Crosses_Opp
#     28. Crosses_Stp
#     29. Crosses_Stp%
#     30. Crs
#     31. CrsPA
#     32. FK
#     33. Fld
#     34. Fls
#     35. G+A-PK
#     36. G-xG
#     37. GA90
#     38. GCA Types_Def
#     39. GCA Types_Fld
#     40. GCA Types_PassDead
#     41. GCA Types_PassLive
#     42. GCA Types_Sh
#     43. GCA Types_TO
#     44. GCA_GCA
#     45. GCA_GCA90
#     46. Goal Kicks_Att
#     47. Goal Kicks_AvgLen
#     48. Goal Kicks_Launch%
#     49. Goals_CK
#     50. Goals_FK
#     51. Goals_GA
#     52. Goals_OG
#     53. Goals_PKA
#     54. Launched_Att
#     55. Launched_Cmp
#     56. Launched_Cmp%
#     57. Min%
#     58. OG
#     59. Off
#     60. Outcomes_Blocks
#     61. Outcomes_Cmp
#     62. Outcomes_Off
#     63. PKcon
#     64. PKwon
#     65. PSxG
#     66. PSxG+/-
#     67. PSxG/SoT
#     68. Pass Types_CK
#     69. Pass Types_Crs
#     70. Pass Types_Dead
#     71. Pass Types_FK
#     72. Pass Types_Live
#     73. Pass Types_Sw
#     74. Pass Types_TB
#     75. Pass Types_TI
#     76. Passes_Att (GK)
#     77. Passes_AvgLen
#     78. Passes_Launch%
#     79. Passes_Thr
#     80. Penalty Kicks_PKA
#     81. Penalty Kicks_PKatt
#     82. Penalty Kicks_PKm
#     83. Penalty Kicks_PKsv
#     84. Penalty Kicks_Save%
#     85. Progression_PrgC
#     86. Progression_PrgP
#     87. Progression_PrgR
#     88. Receiving_PrgR
#     89. Receiving_Rec
#     90. Recov
#     91. SCA Types_Def
#     92. SCA Types_Fld
#     93. SCA Types_PassDead
#     94. SCA Types_PassLive
#     95. SCA Types_Sh
#     96. SCA Types_TO
#     97. SCA_SCA
#     98. SCA_SCA90
#     99. Save%
#    100. Saves
#    101. SoT/90
#    102. SoTA
#    103. Starts_Compl
#    104. Starts_Mn/Start
#    105. Starts_Starts
#    106. Subs_Subs
#    107. Subs_unSub
#    108. Sweeper_#OPA
#    109. Sweeper_#OPA/90
#    110. Sweeper_AvgDist
#    111. Tackles_Att 3rd
#    112. Tackles_Def 3rd
#    113. Tackles_Mid 3rd
#    114. Tackles_Tkl
#    115. Tackles_TklW
#    116. Take-Ons_Att
#    117. Take-Ons_Succ
#    118. Take-Ons_Succ%
#    119. Take-Ons_Tkld
#    120. Take-Ons_Tkld%
#    121. Team Success (xG)_On-Off
#    122. Team Success (xG)_onxG
#    123. Team Success (xG)_onxGA
#    124. Team Success (xG)_xG+/-
#    125. Team Success (xG)_xG+/-90
#    126. Team Success_+/-
#    127. Team Success_+/-90
#    128. Team Success_On-Off
#    129. Team Success_PPM
#    130. Team Success_onG
#    131. Team Success_onGA
#    132. Tkl+Int
#    133. Touches_Att 3rd
#    134. Touches_Att Pen
#    135. Touches_Def 3rd
#    136. Touches_Def Pen
#    137. Touches_Live
#    138. Touches_Mid 3rd
#    139. Touches_Touches
#    140. assists
#    141. clearances
#    142. draws
#    143. errors
#    144. expected_assists
#    145. expected_assists_alt
#    146. expected_goals
#    147. full_matches_equivalent
#    148. goals
#    149. goals_against
#    150. goals_plus_assists
#    151. interceptions
#    152. key_passes
#    153. losses
#    154. matches_played
#    155. matches_started
#    156. minutes_per_match
#    157. minutes_played
#    158. non_penalty_expected_goals
#    159. non_penalty_goals
#    160. non_penalty_xG_plus_xAG
#    161. np:G-xG
#    162. pass_completion_pct
#    163. passes_attempted
#    164. passes_completed
#    165. passes_final_third
#    166. passes_penalty_area
#    167. penalty_attempts
#    168. penalty_goals
#    169. progressive_pass_distance
#    170. progressive_passes
#    171. red_cards
#    172. shots
#    173. shots_on_target
#    174. shots_per_90
#    175. tackles_won
#    176. total_pass_distance
#    177. wins
#    178. xG+xAG
#    179. yellow_cards
#
# 3. MÉTRICAS UNDERSTAT (8):
#     1. understat_key_passes
#     2. understat_np_goals
#     3. understat_np_xg
#     4. understat_player_id
#     5. understat_team_id
#     6. understat_xa
#     7. understat_xg_buildup
#     8. understat_xg_chain
#
# 4. MÉTRICAS PER90 (158):
#      1. /90_per90
#      2. 2CrdY_per90
#      3. A-xAG_per90
#      4. Aerial Duels_Lost_per90
#      5. Aerial Duels_Won_per90
#      6. Blocks_Blocks_per90
#      7. Blocks_Pass_per90
#      8. Blocks_Sh_per90
#      9. CS%_per90
#     10. CS_per90
#     11. Carries_1/3_per90
#     12. Carries_CPA_per90
#     13. Carries_Carries_per90
#     14. Carries_Dis_per90
#     15. Carries_Mis_per90
#     16. Carries_PrgC_per90
#     17. Carries_PrgDist_per90
#     18. Carries_TotDist_per90
#     19. Challenges_Att_per90
#     20. Challenges_Lost_per90
#     21. Challenges_Tkl_per90
#     22. Corner Kicks_In_per90
#     23. Corner Kicks_Out_per90
#     24. Corner Kicks_Str_per90
#     25. Crosses_Opp_per90
#     26. Crosses_Stp_per90
#     27. CrsPA_per90
#     28. Crs_per90
#     29. FK_per90
#     30. Fld_per90
#     31. Fls_per90
#     32. G+A-PK_per90
#     33. G-xG_per90
#     34. GCA Types_Def_per90
#     35. GCA Types_Fld_per90
#     36. GCA Types_PassDead_per90
#     37. GCA Types_PassLive_per90
#     38. GCA Types_Sh_per90
#     39. GCA Types_TO_per90
#     40. GCA_GCA_per90
#     41. Goal Kicks_Att_per90
#     42. Goal Kicks_Launch%_per90
#     43. Goals_CK_per90
#     44. Goals_FK_per90
#     45. Goals_GA_per90
#     46. Goals_OG_per90
#     47. Goals_PKA_per90
#     48. Launched_Att_per90
#     49. Launched_Cmp_per90
#     50. OG_per90
#     51. Off_per90
#     52. Outcomes_Blocks_per90
#     53. Outcomes_Cmp_per90
#     54. Outcomes_Off_per90
#     55. PKcon_per90
#     56. PKwon_per90
#     57. PSxG+/-_per90
#     58. PSxG/SoT_per90
#     59. PSxG_per90
#     60. Pass Types_CK_per90
#     61. Pass Types_Crs_per90
#     62. Pass Types_Dead_per90
#     63. Pass Types_FK_per90
#     64. Pass Types_Live_per90
#     65. Pass Types_Sw_per90
#     66. Pass Types_TB_per90
#     67. Pass Types_TI_per90
#     68. Passes_Att (GK)_per90
#     69. Passes_Launch%_per90
#     70. Passes_Thr_per90
#     71. Penalty Kicks_PKA_per90
#     72. Penalty Kicks_PKatt_per90
#     73. Penalty Kicks_PKm_per90
#     74. Penalty Kicks_PKsv_per90
#     75. Penalty Kicks_Save%_per90
#     76. Progression_PrgC_per90
#     77. Progression_PrgP_per90
#     78. Progression_PrgR_per90
#     79. Receiving_PrgR_per90
#     80. Receiving_Rec_per90
#     81. Recov_per90
#     82. SCA Types_Def_per90
#     83. SCA Types_Fld_per90
#     84. SCA Types_PassDead_per90
#     85. SCA Types_PassLive_per90
#     86. SCA Types_Sh_per90
#     87. SCA Types_TO_per90
#     88. SCA_SCA_per90
#     89. Saves_per90
#     90. SoTA_per90
#     91. Starts_Compl_per90
#     92. Starts_Starts_per90
#     93. Subs_Subs_per90
#     94. Subs_unSub_per90
#     95. Sweeper_#OPA/90_per90
#     96. Sweeper_#OPA_per90
#     97. Sweeper_AvgDist_per90
#     98. Tackles_Att 3rd_per90
#     99. Tackles_Def 3rd_per90
#    100. Tackles_Mid 3rd_per90
#    101. Tackles_TklW_per90
#    102. Tackles_Tkl_per90
#    103. Take-Ons_Att_per90
#    104. Take-Ons_Succ_per90
#    105. Take-Ons_Tkld_per90
#    106. Team Success (xG)_On-Off_per90
#    107. Team Success (xG)_onxGA_per90
#    108. Team Success (xG)_onxG_per90
#    109. Team Success (xG)_xG+/-90_per90
#    110. Team Success (xG)_xG+/-_per90
#    111. Team Success_+/-_per90
#    112. Team Success_On-Off_per90
#    113. Team Success_PPM_per90
#    114. Team Success_onGA_per90
#    115. Team Success_onG_per90
#    116. Tkl+Int_per90
#    117. Touches_Att 3rd_per90
#    118. Touches_Att Pen_per90
#    119. Touches_Def 3rd_per90
#    120. Touches_Def Pen_per90
#    121. Touches_Live_per90
#    122. Touches_Mid 3rd_per90
#    123. Touches_Touches_per90
#    124. assists_per90
#    125. clearances_per90
#    126. errors_per90
#    127. expected_assists_alt_per90
#    128. expected_assists_per90
#    129. expected_goals_per90
#    130. full_matches_equivalent_per90
#    131. goals_against_per90
#    132. goals_per90
#    133. goals_plus_assists_per90
#    134. interceptions_per90
#    135. key_passes_per90
#    136. non_penalty_expected_goals_per90
#    137. non_penalty_goals_per90
#    138. np:G-xG_per90
#    139. passes_attempted_per90
#    140. passes_completed_per90
#    141. passes_final_third_per90
#    142. passes_penalty_area_per90
#    143. penalty_attempts_per90
#    144. penalty_goals_per90
#    145. progressive_pass_distance_per90
#    146. progressive_passes_per90
#    147. red_cards_per90
#    148. shots_on_target_per90
#    149. shots_per90
#    150. tackles_won_per90
#    151. total_pass_distance_per90
#    152. understat_key_passes_per90
#    153. understat_np_goals_per90
#    154. understat_np_xg_per90
#    155. understat_xa_per90
#    156. understat_xg_buildup_per90
#    157. understat_xg_chain_per90
#    158. yellow_cards_per90
#
# 5. PERCENTILES (345):
#    (Mostrando primeros 20 para evitar spam)
#     1. /90_pct
#     2. /90_per90_pct
#     3. 2CrdY_pct
#     4. 2CrdY_per90_pct
#     5. A-xAG_pct
#     6. A-xAG_per90_pct
#     7. Aerial Duels_Lost_pct
#     8. Aerial Duels_Lost_per90_pct
#     9. Aerial Duels_Won%_pct
#    10. Aerial Duels_Won_pct
#    11. Aerial Duels_Won_per90_pct
#    12. Blocks_Blocks_pct
#    13. Blocks_Blocks_per90_pct
#    14. Blocks_Pass_pct
#    15. Blocks_Pass_per90_pct
#    16. Blocks_Sh_pct
#    17. Blocks_Sh_per90_pct
#    18. CS%_pct
#    19. CS%_per90_pct
#    20. CS_pct
#    ... y 325 más
#
# RESUMEN TOTAL:
# - Base: 6
# - FBref: 179
# - Understat: 8
# - Per90: 158
# - Percentiles: 345
# - TOTAL: 695 columnas
#
# Porteros con datos completos: 29 jugadores disponibles

# %%
# 1. Save% vs PSxG+/- - Volumen vs Calidad de paradas
create_diamond_scatter(
    df,
    x_metric='Save%',
    y_metric='PSxG+/-',
    title='1. Calidad vs Eficiencia – Save% vs PSxG+/-',
    save_filename='1_save_pct_vs_psxg_quality.png'
)

# 2. SoTA vs Saves - Workload vs Performance
create_diamond_scatter(
    df,
    x_metric='SoTA',
    y_metric='Saves',
    title='2. Workload vs Performance – SoTA vs Saves',
    save_filename='2_sota_vs_saves_workload.png'
)

# 3. GA90 vs PSxG+/- - Goals conceded vs Expected performance
create_diamond_scatter(
    df,
    x_metric='PSxG+/-',
    y_metric='GA90',
    title='3. Expected vs Reality – PSxG+/- vs GA90',
    save_filename='3_psxg_vs_ga90_reality.png'
)

# 4. CS vs Minutes Played - Clean sheets vs Experience/Consistency
create_diamond_scatter(
    df,
    x_metric='minutes_played',
    y_metric='CS',
    title='4. Experiencia vs Solidez – Minutes vs Clean Sheets',
    save_filename='4_minutes_vs_cs_experience.png'
)

# 5. Penalty Kicks_PKsv vs Penalty Kicks_PKA - Penalty specialist
create_diamond_scatter(
    df,
    x_metric='Penalty Kicks_PKA',
    y_metric='Penalty Kicks_PKsv',
    title='5. Especialistas en Penaltis – PKA vs PKsv',
    save_filename='5_pka_vs_pksv_specialists.png'
)

# 6. Save% vs SoTA - Consistency under pressure
create_diamond_scatter(
    df,
    x_metric='SoTA',
    y_metric='Save%',
    title='6. Consistencia bajo Presión – SoTA vs Save%',
    save_filename='6_sota_vs_save_pct_pressure.png'
)
# Out:
# 2025-09-22 18:57:21,302 - adjustText - WARNING - Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.
# 7 [0.49125777 0.49091634]
# 8 [-0.75305594  0.95847412]
