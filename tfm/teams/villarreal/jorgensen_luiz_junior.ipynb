# %% [markdown]
# # Filip Jørgensen vs Luiz Júnior - PCA Similarity Analysis
# ## Villarreal - Portero
#
# **Context:**
# - Filip Jørgensen: Villarreal 23/24 (vendido 24,5M€ a Chelsea)
# - Luiz Júnior: Fichado por Villarreal 24/25 desde Liga Portuguesa (12M€, stats 23/24 Famalicão)
# - Position: GK
# - Analysis: PCA-based similarity algorithm to validate Luiz Junior as Jørgensen replacement
# - **Data analyzed: Season 23/24** (Jørgensen: Villarreal La Liga, Luiz: Famalicão Portugal)
# - **Note**: Cross-league comparison (La Liga vs Portugal)
# - **Metrics**: Per 90 minutes (not per 100 touches)
#
# **Metodología de Filtrado:**
# - **Pool PCA estandarizado**: Porteros Big 5 + Portugal, 900+ min, max 30 años (criterio físico)
# - **Filtrado post-PCA**: ≤15M€, ≤26 años (criterios económicos aplicados DESPUÉS de calcular similitudes)
# - **Re-ranking**: Rankings 1-N recalculados sobre el pool filtrado

# %%
import pandas as pd
import numpy as np
import sys
import os

# Subir tres niveles desde tfm/teams/villarreal/ hasta data/
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')))

from database.connection import get_db_manager
from tfm.helpers.query_helpers import query_player_pool, add_exogenous_player
from tfm.helpers.algorithms import find_similar_players_cosine

import warnings
warnings.filterwarnings('ignore')

# %%
# Build player pool: GK from Big 5 leagues + Portugal (23/24 season)
big5_leagues = ['ENG-Premier League', 'ESP-La Liga', 'ITA-Serie A', 'GER-Bundesliga', 'FRA-Ligue 1']

pools = []
for league in big5_leagues:
    try:
        pool = query_player_pool(
            league=league,
            season='2324',
            positions=['GK'],
            min_minutes=1000,
            max_age=30
        )
        pools.append(pool)
        print(f"{league}: {len(pool)} jugadores")
    except Exception as e:
        print(f"Error en {league}: {e}")

# Add Portugal (table_type='extras')
# NO usar positions=['GK'] porque transfermarkt_metrics puede ser NULL en extras
# Filtraremos por position (FBref) después
try:
    pool_portugal = query_player_pool(
        league='POR-Primeira Liga',
        season='2324',
        min_minutes=1000,
        min_age=20,
        max_age=30,
        table_type='extras'
    )
    # Filtrar GK por position (FBref) en lugar de Transfermarkt
    pool_portugal = pool_portugal[pool_portugal['position'].str.contains('GK', case=False, na=False)]
    pools.append(pool_portugal)
    print(f"POR-Primeira Liga: {len(pool_portugal)} jugadores")
except Exception as e:
    print(f"Error en Portugal: {e}")

pool_df = pd.concat(pools, ignore_index=True)

print(f"\nPool total: {len(pool_df)} jugadores")
print(f"\nDistribución por liga:")
print(pool_df['league'].value_counts())
# Out:
# 2026-01-18 15:23:53,398 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-18 15:23:53,532 - database.connection - INFO - Database connection successful
# 2026-01-18 15:23:53,558 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-18 15:23:53,580 - database.connection - INFO - Database connection successful
# 2026-01-18 15:23:53,601 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-18 15:23:53,624 - database.connection - INFO - Database connection successful
# 2026-01-18 15:23:53,648 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-18 15:23:53,669 - database.connection - INFO - Database connection successful
# 2026-01-18 15:23:53,689 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-18 15:23:53,711 - database.connection - INFO - Database connection successful
# 2026-01-18 15:23:53,730 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-18 15:23:53,749 - database.connection - INFO - Database connection successful
# ENG-Premier League: 17 jugadores
# ESP-La Liga: 19 jugadores
# ITA-Serie A: 15 jugadores
# GER-Bundesliga: 10 jugadores
# FRA-Ligue 1: 14 jugadores
# POR-Primeira Liga: 14 jugadores
#
# Pool total: 89 jugadores
#
# Distribución por liga:
# league
# ESP-La Liga           19
# ENG-Premier League    17
# ITA-Serie A           15
# FRA-Ligue 1           14
# POR-Primeira Liga     14
# GER-Bundesliga        10
# Name: count, dtype: int64

# %%
full_df = pool_df.copy()
print(f"DataFrame con todos los jugadores: {len(full_df)} jugadores")
# Out:
# DataFrame con todos los jugadores: 89 jugadores

# %%
# Add Jørgensen as exogenous player
full_df = add_exogenous_player(
    pool_df=pool_df,
    player_name='Jørgensen',
    league='ESP-La Liga',
    season='2324',
    team='Villarreal'
)

print(f"DataFrame con Target: {len(full_df)} jugadores")
# Out:
# 2026-01-18 15:23:53,827 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-18 15:23:53,851 - database.connection - INFO - Database connection successful
# Added exogenous player: Filip Jørgensen (Villarreal, ESP-La Liga 2324)
# Total players in DataFrame: 90
# DataFrame con Target: 90 jugadores

# %%
def extract_metrics(df, col_name):
    result = pd.DataFrame(index=df.index)
    all_keys = set()
    for _, row in df.iterrows():
        if isinstance(row[col_name], dict):
            all_keys.update(row[col_name].keys())
    
    for key in all_keys:
        values = []
        for _, row in df.iterrows():
            if isinstance(row[col_name], dict) and key in row[col_name]:
                raw_value = row[col_name][key]
                converted_value = _convert_to_float(raw_value)
                values.append(converted_value)
            else:
                values.append(np.nan)
        
        valid_count = pd.Series(values).notna().sum()
        if valid_count >= 5:
            result[key] = values
    
    return result

def _convert_to_float(value):
    if isinstance(value, (int, float)):
        return float(value)
    if value is None or pd.isna(value):
        return np.nan
    if isinstance(value, str):
        if value.strip() == '' or value.lower().strip() in ['nan', 'none', 'null', '-']:
            return np.nan
        try:
            return float(value)
        except (ValueError, TypeError):
            return np.nan
    return np.nan

fbref_nums = extract_metrics(full_df, 'fbref_metrics')
understat_nums = extract_metrics(full_df, 'understat_metrics')
transfermarkt_nums = extract_metrics(full_df, 'transfermarkt_metrics')

print(f"FBref: {fbref_nums.shape[1]} métricas")
print(f"Understat: {understat_nums.shape[1]} métricas")
print(f"Transfermarkt: {transfermarkt_nums.shape[1]} campos")
# Out:
# FBref: 183 métricas
# Understat: 10 métricas
# Transfermarkt: 2 campos

# %%
exclude_normalization = {
    'minutes_played', 'age', 'birth_year', 'games_started', 'minutes_per_game',
    'minutes_per_start', 'games', 'games_subs', 'unused_sub', 'points_per_game',
    'on_goals_for', 'on_goals_against', 'plus_minus', 'plus_minus_per90',
    'plus_minus_wowy', 'on_xg_for', 'on_xg_against', 'xg_plus_minus',
    'xg_plus_minus_per90', 'xg_plus_minus_wowy'
}

fbref_per90 = fbref_nums.loc[:, ~fbref_nums.columns.isin(exclude_normalization)]
fbref_per90 = (fbref_per90.div(fbref_nums['minutes_played'], axis=0) * 90).round(3)
fbref_per90.columns = [f'{col}_per90' for col in fbref_per90.columns]

understat_per90 = understat_nums.loc[:, ~understat_nums.columns.isin(exclude_normalization)]
understat_per90 = (understat_per90.div(fbref_nums['minutes_played'], axis=0) * 90).round(3)
understat_per90.columns = [f'{col}_per90' for col in understat_per90.columns]

print(f"Per90 FBref: {fbref_per90.shape[1]} columnas")
print(f"Per90 Understat: {understat_per90.shape[1]} columnas")
# Out:
# Per90 FBref: 182 columnas
# Per90 Understat: 10 columnas

# %%
base_cols = ['unique_player_id', 'player_name', 'team', 'league', 'season', 'position', 'age']

df_final = pd.concat([
    full_df[base_cols],
    fbref_nums,
    understat_nums,
    transfermarkt_nums,
    fbref_per90,
    understat_per90
], axis=1)

print(f"DataFrame final: {df_final.shape[0]} jugadores × {df_final.shape[1]} columnas")
# Out:
# DataFrame final: 90 jugadores × 394 columnas

# %%
# Identify target (Jørgensen) and replacement (Luiz Junior)
target = df_final[df_final['player_name'].str.contains('Jørgensen', case=False, na=False)]
target = target[target['team'].str.contains('Villarreal', case=False, na=False)]
replacement = df_final[df_final['player_name'].str.contains('Luiz', case=False, na=False)]
replacement = replacement[replacement['team'].str.contains('Famalicão', case=False, na=False)]

if len(target) == 0:
    raise ValueError("Target no encontrado")
if len(replacement) == 0:
    raise ValueError("Replacement no encontrado")

target_id = target.iloc[0]['unique_player_id']
replacement_id = replacement.iloc[0]['unique_player_id']

print(f"Target: {target.iloc[0]['player_name']} ({target.iloc[0]['team']})") 
print(f"  ID: {target_id}")
print(f"\nReemplazo: {replacement.iloc[0]['player_name']} ({replacement.iloc[0]['team']})")
print(f"  ID: {replacement_id}")
# Out:
# Target: Filip Jørgensen (Villarreal)
#   ID: f9593b93839dddbb
#
# Reemplazo: Luiz Lúcio Reis Júnior (Famalicão)
#   ID: f8b130603b3260da

# %%
# Run PCA similarity algorithm
result = find_similar_players_cosine(
    df=df_final,
    target_player_id=target_id,
    n_similar=30,
    pca_variance=0.85,
    replacement_id=replacement_id,
    robust_scaling=False,
    return_all_scores=True
)
# Out:
# Target: Filip Jørgensen (Villarreal, ESP-La Liga)
# Features: 168 (per 90, excl. GK)
# Jugadores: 90 (eliminados 0 con NaNs CORE)
# PCA: 11 componentes (varianza: 85.8%)
# Reducción: 168 → 11 dimensiones
# Top-30 encontrados
# Rango similitud: [0.2712, 0.7686]

# %%
# Filtrar resultados por restricciones de mercado (post-PCA)
MAX_VALUE = 15  # Millones €
MAX_AGE_FILTER = 26  # Edad máxima para filtrado económico

# Extraer datos del full_df
def get_market_value(player_id):
    player_row = full_df[full_df['unique_player_id'] == player_id]
    if len(player_row) == 0:
        return None
    
    # Hardcode para Luiz Júnior (tabla extras Portugal sin market_value)
    player_name = player_row.iloc[0].get('player_name', '')
    if 'Luiz' in player_name and 'Júnior' in player_name:
        return 6.0  # 6M€
    
    tm_metrics = player_row.iloc[0].get('transfermarkt_metrics')
    if isinstance(tm_metrics, dict):
        val = tm_metrics.get('transfermarkt_market_value_eur')
        return float(val) / 1_000_000 if val else None
    return None

def get_age(player_id):
    player_row = full_df[full_df['unique_player_id'] == player_id]
    if len(player_row) == 0:
        return None
    return player_row.iloc[0].get('age')

# Obtener ALL scores (no solo top-30)
all_scores_df = result['all_scores'].copy()
all_scores_df['market_value_m'] = all_scores_df['unique_player_id'].apply(get_market_value)
all_scores_df['age'] = all_scores_df['unique_player_id'].apply(get_age)

# Filtrar TODO el pool por edad/valor de mercado
pool_filtrado_completo = all_scores_df[
    (all_scores_df['market_value_m'] <= MAX_VALUE) &
    (all_scores_df['age'] <= MAX_AGE_FILTER)
].copy()

# Re-rankear pool filtrado completo
pool_filtrado_completo = pool_filtrado_completo.sort_values('cosine_similarity', ascending=False).reset_index(drop=True)
pool_filtrado_completo['rank_filtrado'] = range(1, len(pool_filtrado_completo) + 1)

# Top-30 del pool completo (para display)
similar_df = result['similar_players'].copy()
similar_df['market_value_m'] = similar_df['unique_player_id'].apply(get_market_value)
similar_df['age'] = similar_df['unique_player_id'].apply(get_age)

print("TOP 30 - Pool Completo")
print("="*80)
print(similar_df[['rank', 'player_name', 'team', 'age', 'market_value_m', 'cosine_similarity']].head(30).to_string(index=False))

# Top-15 del pool filtrado (para display)
viable_df = pool_filtrado_completo.head(15).copy()

print(f"\n\nTOP 15 - Pool Filtrado (≤{MAX_VALUE}M€, ≤{MAX_AGE_FILTER} años)")
print("="*80)
print(f"Total jugadores en pool filtrado: {len(pool_filtrado_completo)}")
print("\n" + viable_df[['rank_filtrado', 'player_name', 'team', 'age', 'market_value_m', 'cosine_similarity']].head(15).to_string(index=False))

# REPLACEMENT VALIDATION
print("\n" + "="*80)
print("REPLACEMENT VALIDATION")
print("="*80)

# Get replacement name for display
replacement_name = replacement.iloc[0]['player_name'] if len(replacement) > 0 else "Replacement"

if replacement_id in pool_filtrado_completo['unique_player_id'].values:
    luiz_row_filtered = pool_filtrado_completo[pool_filtrado_completo['unique_player_id'] == replacement_id].iloc[0]

    # Info del pool completo
    repl_info = result.get('replacement_info')
    rank_completo = repl_info['rank'] if repl_info else None

    print(f"✓ {replacement_name} encontrado en ambos pools")
    print(f"  Rank pool completo: {rank_completo}")
    print(f"  Rank pool filtrado: {luiz_row_filtered['rank_filtrado']}/{len(pool_filtrado_completo)}")
    print(f"  Similitud: {luiz_row_filtered['cosine_similarity']:.4f}")
    print(f"  Age: {luiz_row_filtered['age']} | Market value: {luiz_row_filtered['market_value_m']:.1f}M€")
    print(f"\n  Status: VALIDADO" if luiz_row_filtered['rank_filtrado'] <= 10 else f"  Status: Rank {luiz_row_filtered['rank_filtrado']}")
else:
    repl_info = result.get('replacement_info')
    if repl_info and repl_info.get('rank'):
        rank_completo = repl_info['rank']
        age = get_age(replacement_id)
        market_value = get_market_value(replacement_id)

        print(f"✓ {replacement_name} en pool completo, NO en pool filtrado")
        print(f"  Rank pool completo: {rank_completo}")
        print(f"  Age: {age} | Market value: {market_value:.1f}M€")

        reasons = []
        if market_value and market_value > MAX_VALUE:
            reasons.append(f"valor {market_value:.1f}M€ > {MAX_VALUE}M€")
        if age and age > MAX_AGE_FILTER:
            reasons.append(f"edad {age} > {MAX_AGE_FILTER}")
        print(f"  Excluido: {', '.join(reasons)}")
    else:
        print(f"✗ {replacement_name} NO encontrado en pool PCA")
# Out:
# TOP 30 - Pool Completo
# ================================================================================
#  rank             player_name           team  age  market_value_m  cosine_similarity
#     1              Yvon Mvogo        Lorient   29             3.0           0.768648
#     2           Yehvann Diouf          Reims   23             8.0           0.749234
#     3            Noah Atubolu       Freiburg   21            10.0           0.742369
#     4             André Onana Manchester Utd   27            35.0           0.735845
#     5          Stefano Turati      Frosinone   21             7.0           0.719556
#     6          Marvin Schwäbe           Köln   28             4.0           0.698650
#     7       Guglielmo Vicario      Tottenham   26            35.0           0.690475
#     8          Moritz Nicolas       Gladbach   25             2.5           0.564397
#     9            Alban Lafont         Nantes   24             9.0           0.555969
#    10             Brice Samba           Lens   29            15.0           0.518700
#    11 Ignacio De Arruabarrena         Arouca   26             2.0           0.498331
#    12                  Andrew Gil Vicente FC   22             NaN           0.497869
#    13         Thomas Kaminski     Luton Town   30             3.0           0.497021
#    14          Fabijan Buntić         Vizela   26             0.6           0.470374
#    15          Marcel Schuhen   Darmstadt 98   30             0.8           0.454692
#    16          Luís Maximiano        Almería   24             5.0           0.449487
#    17         Frederik Rønnow   Union Berlin   30             4.5           0.437419
#    18            Gregor Kobel       Dortmund   25            40.0           0.420665
#    19                 José Sá         Wolves   30            14.0           0.395215
#    20          James Trafford        Burnley   20            18.0           0.387228
#    21           Ivan Provedel          Lazio   29            14.0           0.371601
#    22            Mike Maignan          Milan   28            38.0           0.359456
#    23         Bart Verbruggen       Brighton   20            18.0           0.358174
#    24     Michele Di Gregorio          Monza   26            18.0           0.341218
#    25        Michael Zetterer  Werder Bremen   28             3.0           0.326017
#    26               Mory Diaw  Clermont Foot   30             1.8           0.324203
#    27           Álvaro Vallés     Las Palmas   26            12.0           0.300335
#    28            Marcin Bułka           Nice   23            20.0           0.279887
#    29       Emiliano Martínez    Aston Villa   30            28.0           0.272220
#    30       Wladimiro Falcone          Lecce   28             5.0           0.271204
#
#
# TOP 15 - Pool Filtrado (≤15M€, ≤26 años)
# ================================================================================
# Total jugadores en pool filtrado: 27
#
#  rank_filtrado             player_name       team  age  market_value_m  cosine_similarity
#              1           Yehvann Diouf      Reims   23             8.0           0.749234
#              2            Noah Atubolu   Freiburg   21            10.0           0.742369
#              3          Stefano Turati  Frosinone   21             7.0           0.719556
#              4          Moritz Nicolas   Gladbach   25             2.5           0.564397
#              5            Alban Lafont     Nantes   24             9.0           0.555969
#              6 Ignacio De Arruabarrena     Arouca   26             2.0           0.498331
#              7          Fabijan Buntić     Vizela   26             0.6           0.470374
#              8          Luís Maximiano    Almería   24             5.0           0.449487
#              9           Álvaro Vallés Las Palmas   26            12.0           0.300335
#             10             Finn Dahmen   Augsburg   25             5.0           0.251732
#             11         Alexander Nübel  Stuttgart   26            12.0           0.242577
#             12              Alex Meret     Napoli   26            12.0           0.228345
#             13          Josep Martinez      Genoa   25             8.0           0.225760
#             14            Philipp Köhn     Monaco   25             5.0           0.209543
#             15  Luiz Lúcio Reis Júnior  Famalicão   22             6.0           0.193328
#
# ================================================================================
# REPLACEMENT VALIDATION
# ================================================================================
# ✓ Luiz Lúcio Reis Júnior encontrado en ambos pools
#   Rank pool completo: 41
#   Rank pool filtrado: 15/27
#   Similitud: 0.1933
#   Age: 22 | Market value: 6.0M€
#   Status: Rank 15

# %%
from tfm.helpers.viz_helpers import plot_top10_ranking

# Preparar pool filtrado completo para viz
pool_viz = pool_filtrado_completo.copy()

# Eliminar rank original del PCA (viene de all_scores)
if 'rank' in pool_viz.columns:
    pool_viz = pool_viz.drop(columns=['rank'])

# Renombrar rank_filtrado a rank para que la viz lo use
pool_viz = pool_viz.rename(columns={'rank_filtrado': 'rank'})

# NO quitar age/market_value - ya tienen los hardcodes correctos

# Preparar result para viz
result_viable = result.copy()
result_viable['similar_players'] = pool_viz

# Override replacement_info con rank filtrado + market_value
if replacement_id in pool_filtrado_completo['unique_player_id'].values:
    luiz_row = pool_filtrado_completo[pool_filtrado_completo['unique_player_id'] == replacement_id].iloc[0]
    result_viable['replacement_info'] = {
        'player_name': luiz_row['player_name'],
        'unique_player_id': replacement_id,
        'team': luiz_row['team'],
        'league': luiz_row['league'],
        'season': luiz_row['season'],
        'rank': int(luiz_row['rank_filtrado']),
        'cosine_similarity': float(luiz_row['cosine_similarity']),
        'age': int(luiz_row['age']),
        'market_value_m': float(luiz_row['market_value_m'])  # Hardcode 6.0M€
    }

output_path = plot_top10_ranking(
    result=result_viable,
    df_data=full_df,
    save_path='jorgensen_luiz_junior_top10_ranking.png',
    target_face_path='/home/jaime/FD/data/blog/caras/tfm/jorgensen.png',
    highlight_target=True,
    dpi=300
)

print(f"Visualización: {output_path}")

from IPython.display import Image, display
display(Image(filename=output_path))
# Out:
# Visualización: /home/jaime/FD/data/tfm/teams/villarreal/jorgensen_luiz_junior_top10_ranking.png

# %%
# PCA Information
pca_info = result['pca_info']

print("\nINFORMACIÓN PCA")
print("="*80)
print(f"Dimensiones originales: {pca_info['original_dimensions']}")
print(f"Componentes retenidos: {pca_info['n_components']}")
print(f"Varianza explicada: {pca_info['explained_variance_ratio']:.1%}")
print(f"Ratio de compresión: {pca_info['compression_ratio']:.1%}")
print("\nVarianza por componente (top-5):")
for i, var in enumerate(pca_info['top_5_components_variance'], 1):
    print(f"  PC{i}: {var:.1%}")
# Out:
# INFORMACIÓN PCA
# ================================================================================
# Dimensiones originales: 168
# Componentes retenidos: 11
# Varianza explicada: 85.8%
# Ratio de compresión: 6.5%
#
# Varianza por componente (top-5):
#   PC1: 47.0%
#   PC2: 9.7%
#   PC3: 7.2%
#   PC4: 5.5%
#   PC5: 4.4%

# %%
# Similarity Score Distribution
dist = result['score_distribution']

print("\nDISTRIBUCIÓN DE SIMILITUDES")
print("="*80)
print(f"Mínimo:   {dist['min']:.4f}")
print(f"Q5:       {dist['q5']:.4f}")
print(f"Q25:      {dist['q25']:.4f}")
print(f"Mediana:  {dist['median']:.4f}")
print(f"Q75:      {dist['q75']:.4f}")
print(f"Q95:      {dist['q95']:.4f}")
print(f"Máximo:   {dist['max']:.4f}")
print(f"Media:    {dist['mean']:.4f}")
print(f"Desv.Est: {dist['std']:.4f}")
# Out:
# DISTRIBUCIÓN DE SIMILITUDES
# ================================================================================
# Mínimo:   -0.4983
# Q5:       -0.3651
# Q25:      -0.0331
# Mediana:  0.1537
# Q75:      0.3585
# Q95:      0.7122
# Máximo:   0.7686
# Media:    0.1543
# Desv.Est: 0.3049
