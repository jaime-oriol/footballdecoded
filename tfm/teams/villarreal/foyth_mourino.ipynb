# %% [markdown]
# # Juan Foyth vs Santiago Mouriño - PCA Similarity Analysis
# ## Villarreal - Lateral Derecho
#
# **Context:**
# - Juan Foyth: Villarreal 24/25, right back
# - Santiago Mouriño: Replacement analysis from Alavés 24/25
# - Position: RB (lateral derecho in Transfermarkt)
# - Analysis: PCA-based similarity algorithm to validate Mouriño as Foyth replacement
#
# **Metodología:**
# - **Pool PCA estandarizado**: RB, 1000+ min, max 30 años (SIN filtros económicos)
# - **Ventaja**: PCA independiente de filtros económicos arbitrarios → evita cherry-picking
# - **Filtros post-PCA**: Se aplican DESPUÉS para mostrar opciones viables (≤15M€, 22-28 años)

# %%
import pandas as pd
import numpy as np
import sys
import os

# Subir tres niveles desde tfm/teams/villarreal/ hasta data/
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')))

from database.connection import get_db_manager
from tfm.helpers.query_helpers import query_player_pool, add_exogenous_player
from tfm.helpers.algorithms import find_similar_players_cosine

import warnings
warnings.filterwarnings('ignore')

# %%
# Pool PCA estandarizado (SIN filtros económicos)
big5_leagues = ['ENG-Premier League', 'ESP-La Liga', 'ITA-Serie A', 'GER-Bundesliga', 'FRA-Ligue 1']

pools = []
for league in big5_leagues:
    try:
        pool = query_player_pool(
            league=league,
            season='2425',
            positions=['RB'],
            min_minutes=1000,
            max_age=30  # Criterio físico, NO económico
        )
        pools.append(pool)
        print(f"{league}: {len(pool)} jugadores")
    except Exception as e:
        print(f"Error en {league}: {e}")

pool_df = pd.concat(pools, ignore_index=True)

print(f"\nPool PCA (estandarizado): {len(pool_df)} jugadores")
print(f"\nDistribución por liga:")
print(pool_df['league'].value_counts())
# Out:
# 2026-01-07 17:27:27,635 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-07 17:27:27,962 - database.connection - INFO - Database connection successful
# 2026-01-07 17:27:28,081 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-07 17:27:28,113 - database.connection - INFO - Database connection successful
# 2026-01-07 17:27:28,161 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-07 17:27:28,190 - database.connection - INFO - Database connection successful
# 2026-01-07 17:27:28,250 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-07 17:27:28,278 - database.connection - INFO - Database connection successful
# ENG-Premier League: 22 jugadores
# ESP-La Liga: 19 jugadores
# ITA-Serie A: 23 jugadores
# 2026-01-07 17:27:28,353 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-07 17:27:28,389 - database.connection - INFO - Database connection successful
# GER-Bundesliga: 21 jugadores
# FRA-Ligue 1: 19 jugadores
#
# Pool PCA (estandarizado): 104 jugadores
#
# Distribución por liga:
# league
# ITA-Serie A           23
# ENG-Premier League    22
# GER-Bundesliga        21
# ESP-La Liga           19
# FRA-Ligue 1           19
# Name: count, dtype: int64

# %%
# Both players already in pool (Foyth: Villarreal, Mouriño: Alavés)
full_df = pool_df.copy()
print(f"DataFrame con todos los jugadores: {len(full_df)} jugadores")
# Out:
# DataFrame con todos los jugadores: 104 jugadores

# %%
# Add Johan Mojica as exogenous player (target) - buscar en ESP-La Liga 23/24
full_df = add_exogenous_player(
    pool_df=pool_df,
    player_name='Foyth',
    league='ESP-La Liga',
    season='2425',
    team=None
)

print(f"DataFrame con Target: {len(full_df)} jugadores")
# Out:
# 2026-01-07 17:27:28,500 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-07 17:27:28,536 - database.connection - INFO - Database connection successful
# Added exogenous player: Juan Foyth (Villarreal, ESP-La Liga 2425)
# Total players in DataFrame: 105
# DataFrame con Target: 105 jugadores

# %%
def extract_metrics(df, col_name):
    result = pd.DataFrame(index=df.index)
    all_keys = set()
    for _, row in df.iterrows():
        if isinstance(row[col_name], dict):
            all_keys.update(row[col_name].keys())
    
    for key in all_keys:
        values = []
        for _, row in df.iterrows():
            if isinstance(row[col_name], dict) and key in row[col_name]:
                raw_value = row[col_name][key]
                converted_value = _convert_to_float(raw_value)
                values.append(converted_value)
            else:
                values.append(np.nan)
        
        valid_count = pd.Series(values).notna().sum()
        if valid_count >= 5:
            result[key] = values
    
    return result

def _convert_to_float(value):
    if isinstance(value, (int, float)):
        return float(value)
    if value is None or pd.isna(value):
        return np.nan
    if isinstance(value, str):
        if value.strip() == '' or value.lower().strip() in ['nan', 'none', 'null', '-']:
            return np.nan
        try:
            return float(value)
        except (ValueError, TypeError):
            return np.nan
    return np.nan

fbref_nums = extract_metrics(full_df, 'fbref_metrics')
understat_nums = extract_metrics(full_df, 'understat_metrics')
transfermarkt_nums = extract_metrics(full_df, 'transfermarkt_metrics')

print(f"FBref: {fbref_nums.shape[1]} métricas")
print(f"Understat: {understat_nums.shape[1]} métricas")
print(f"Transfermarkt: {transfermarkt_nums.shape[1]} campos")
# Out:
# FBref: 185 métricas
# Understat: 10 métricas
# Transfermarkt: 2 campos

# %%
exclude_normalization = {
    'minutes_played', 'age', 'birth_year', 'games_started', 'minutes_per_game',
    'minutes_per_start', 'games', 'games_subs', 'unused_sub', 'points_per_game',
    'on_goals_for', 'on_goals_against', 'plus_minus', 'plus_minus_per90',
    'plus_minus_wowy', 'on_xg_for', 'on_xg_against', 'xg_plus_minus',
    'xg_plus_minus_per90', 'xg_plus_minus_wowy', 'Touches_Touches'
}

fbref_per100 = fbref_nums.loc[:, ~fbref_nums.columns.isin(exclude_normalization)]
fbref_per100 = (fbref_per100.div(fbref_nums['Touches_Touches'], axis=0) * 100).round(3)
fbref_per100.columns = [f'{col}_per100touches' for col in fbref_per100.columns]

understat_per100 = understat_nums.loc[:, ~understat_nums.columns.isin(exclude_normalization)]
understat_per100 = (understat_per100.div(fbref_nums['Touches_Touches'], axis=0) * 100).round(3)
understat_per100.columns = [f'{col}_per100touches' for col in understat_per100.columns]

print(f"Per100touches FBref: {fbref_per100.shape[1]} columnas")
print(f"Per100touches Understat: {understat_per100.shape[1]} columnas")
# Out:
# Per100touches FBref: 183 columnas
# Per100touches Understat: 10 columnas

# %%
base_cols = ['unique_player_id', 'player_name', 'team', 'league', 'season', 'position', 'age']

df_final = pd.concat([
    full_df[base_cols],
    fbref_nums,
    understat_nums,
    transfermarkt_nums,
    fbref_per100,
    understat_per100
], axis=1)

print(f"DataFrame final: {df_final.shape[0]} jugadores × {df_final.shape[1]} columnas")
# Out:
# DataFrame final: 105 jugadores × 397 columnas

# %%
# Identify target (Foyth) and replacement (Mouriño)
target = df_final[df_final['player_name'].str.contains('Foyth', case=False, na=False)]
replacement = df_final[df_final['player_name'].str.contains('Mouriño', case=False, na=False)]

if len(target) == 0:
    raise ValueError("Target no encontrado")
if len(replacement) == 0:
    raise ValueError("Replacement no encontrado")

target_id = target.iloc[0]['unique_player_id']
replacement_id = replacement.iloc[0]['unique_player_id']

print(f"Target: {target.iloc[0]['player_name']} ({target.iloc[0]['team']})")
print(f"  ID: {target_id}")
print(f"\nReemplazo: {replacement.iloc[0]['player_name']} ({replacement.iloc[0]['team']})")
print(f"  ID: {replacement_id}")
# Out:
# Target: Juan Foyth (Villarreal)
#   ID: 48fc0181ba9dfbd0
#
# Reemplazo: Santiago Mouriño (Alavés)
#   ID: c7250970b01ea2a9

# %%
# Run PCA similarity algorithm
result = find_similar_players_cosine(
    df=df_final,
    target_player_id=target_id,
    n_similar=30,
    pca_variance=0.85,
    replacement_id=replacement_id,
    robust_scaling=False,
    return_all_scores=True  # IMPORTANTE: obtener scores de TODOS los jugadores
)
# Out:
# Target: Juan Foyth (Villarreal, ESP-La Liga)
# Features: 170 (per 100 touches, excl. GK)
# Jugadores: 105 (eliminados 0 con NaNs CORE)
# PCA: 23 componentes (varianza: 85.5%)
# Reducción: 170 → 23 dimensiones
# Top-30 encontrados
# Rango similitud: [0.1461, 0.7442]

# %%
# Filtrar resultados por restricciones de mercado (post-PCA)
MAX_VALUE = 20  # Millones €
MAX_AGE_FILTER = 26  # Edad máxima para filtrado económico

# Extraer datos del full_df
def get_market_value(player_id):
    player_row = full_df[full_df['unique_player_id'] == player_id]
    if len(player_row) == 0:
        return None
    tm_metrics = player_row.iloc[0].get('transfermarkt_metrics')
    if isinstance(tm_metrics, dict):
        val = tm_metrics.get('transfermarkt_market_value_eur')
        return float(val) / 1_000_000 if val else None
    return None

def get_age(player_id):
    player_row = full_df[full_df['unique_player_id'] == player_id]
    if len(player_row) == 0:
        return None
    return player_row.iloc[0].get('age')

# Obtener ALL scores (no solo top-30)
all_scores_df = result['all_scores'].copy()
all_scores_df['market_value_m'] = all_scores_df['unique_player_id'].apply(get_market_value)
all_scores_df['age'] = all_scores_df['unique_player_id'].apply(get_age)

# Filtrar TODO el pool por edad/valor de mercado
pool_filtrado_completo = all_scores_df[
    (all_scores_df['market_value_m'] <= MAX_VALUE) &
    (all_scores_df['age'] >= MIN_AGE_FILTER) &
    (all_scores_df['age'] <= MAX_AGE_FILTER)
].copy()

# Re-rankear pool filtrado completo
pool_filtrado_completo = pool_filtrado_completo.sort_values('cosine_similarity', ascending=False).reset_index(drop=True)
pool_filtrado_completo['rank_filtrado'] = range(1, len(pool_filtrado_completo) + 1)

# Top-30 del pool completo (para display)
similar_df = result['similar_players'].copy()
similar_df['market_value_m'] = similar_df['unique_player_id'].apply(get_market_value)
similar_df['age'] = similar_df['unique_player_id'].apply(get_age)

print("TOP 30 - Pool Completo")
print("="*80)
print(similar_df[['rank', 'player_name', 'team', 'age', 'market_value_m', 'cosine_similarity']].head(30).to_string(index=False))

# Top-15 del pool filtrado (para display)
viable_df = pool_filtrado_completo.head(15).copy()

print(f"\n\nTOP 15 - Pool Filtrado (≤{MAX_VALUE}M€, {MIN_AGE_FILTER}-{MAX_AGE_FILTER} años)")
print("="*80)
print(f"Total jugadores en pool filtrado: {len(pool_filtrado_completo)}")
print("\n" + viable_df[['rank_filtrado', 'player_name', 'team', 'age', 'market_value_m', 'cosine_similarity']].head(15).to_string(index=False))

# REPLACEMENT VALIDATION
print("\n" + "="*80)
print("REPLACEMENT VALIDATION")
print("="*80)

# Get replacement name for display
replacement_name = replacement.iloc[0]['player_name'] if len(replacement) > 0 else "Replacement"

if replacement_id in pool_filtrado_completo['unique_player_id'].values:
    mourino_row_filtered = pool_filtrado_completo[pool_filtrado_completo['unique_player_id'] == replacement_id].iloc[0]

    # Info del pool completo
    repl_info = result.get('replacement_info')
    rank_completo = repl_info['rank'] if repl_info else None

    print(f"✓ {replacement_name} encontrado en ambos pools")
    print(f"  Rank pool completo: {rank_completo}")
    print(f"  Rank pool filtrado: {mourino_row_filtered['rank_filtrado']}/{len(pool_filtrado_completo)}")
    print(f"  Similitud: {mourino_row_filtered['cosine_similarity']:.4f}")
    print(f"  Age: {mourino_row_filtered['age']} | Market value: {mourino_row_filtered['market_value_m']:.1f}M€")
    print(f"\n  Status: VALIDADO" if mourino_row_filtered['rank_filtrado'] <= 10 else f"  Status: Rank {mourino_row_filtered['rank_filtrado']}")
else:
    repl_info = result.get('replacement_info')
    if repl_info and repl_info.get('rank'):
        rank_completo = repl_info['rank']
        age = get_age(replacement_id)
        market_value = get_market_value(replacement_id)

        print(f"✓ {replacement_name} en pool completo, NO en pool filtrado")
        print(f"  Rank pool completo: {rank_completo}")
        print(f"  Age: {age} | Market value: {market_value:.1f}M€")

        reasons = []
        if market_value and market_value > MAX_VALUE:
            reasons.append(f"valor {market_value:.1f}M€ > {MAX_VALUE}M€")
        if age and age < MIN_AGE_FILTER:
            reasons.append(f"edad {age} < {MIN_AGE_FILTER}")
        if age and age > MAX_AGE_FILTER:
            reasons.append(f"edad {age} > {MAX_AGE_FILTER}")
        print(f"  Excluido: {', '.join(reasons)}")
    else:
        print(f"✗ {replacement_name} NO encontrado en pool PCA")
# Out:
# TOP 30 - Pool Completo
# ================================================================================
#  rank          player_name            team  age  market_value_m  cosine_similarity
#     1       Wilfried Singo          Monaco   23            25.0           0.744193
#     2        Hans Hateboer          Rennes   30             2.5           0.629279
#     3     Enrico Del Prato           Parma   24             6.5           0.625568
#     4           Guela Doué      Strasbourg   21            18.0           0.530623
#     5         Jake O'Brien         Everton   23            18.0           0.522497
#     6     Timothy Castagne          Fulham   28            13.0           0.465863
#     7     Santiago Mouriño          Alavés   22             3.0           0.459899
#     8 Lutsharel Geertruida      RB Leipzig   24            20.0           0.459253
#     9           Joe Scally        Gladbach   21            10.0           0.433988
#    10         Marnon Busch      Heidenheim   29             1.2           0.413336
#    11        Nicolò Savona        Juventus   21            12.0           0.405525
#    12           Malo Gusto         Chelsea   21            35.0           0.395200
#    13          Reece James         Chelsea   24            30.0           0.363908
#    14       Gabriele Zappa        Cagliari   24             4.0           0.353030
#    15           Rico Lewis Manchester City   19            40.0           0.350604
#    16          Tim Oermann          Bochum   20             5.0           0.331876
#    17         Jules Koundé       Barcelona   25            65.0           0.329471
#    18           Zeki Çelik            Roma   27             6.0           0.309116
#    19           Kenny Tete          Fulham   28            13.0           0.298361
#    20 Valentino Livramento   Newcastle Utd   21            40.0           0.297954
#    21       Arnau Martinez          Girona   21            10.0           0.263145
#    22       Josha Vagnoman       Stuttgart   23            10.0           0.245589
#    23         James Justin  Leicester City   26            13.0           0.235346
#    24  Giovanni Di Lorenzo          Napoli   30            12.0           0.232376
#    25              Douglas          Nantes   27             NaN           0.214499
#    26    Noussair Mazraoui  Manchester Utd   26            25.0           0.209407
#    27            Emil Holm         Bologna   24             8.0           0.166424
#    28       Omar El Hilali        Espanyol   20            15.0           0.163619
#    29    Rasmus Kristensen  Eint Frankfurt   27            14.0           0.146341
#    30    Frederic Guilbert           Lecce   29             2.5           0.146128
#
#
# TOP 15 - Pool Filtrado (≤20M€, 22-26 años)
# ================================================================================
# Total jugadores en pool filtrado: 45
#
#  rank_filtrado            player_name            team  age  market_value_m  cosine_similarity
#              1       Enrico Del Prato           Parma   24             6.5           0.625568
#              2           Jake O'Brien         Everton   23            18.0           0.522497
#              3       Santiago Mouriño          Alavés   22             3.0           0.459899
#              4   Lutsharel Geertruida      RB Leipzig   24            20.0           0.459253
#              5         Gabriele Zappa        Cagliari   24             4.0           0.353030
#              6         Josha Vagnoman       Stuttgart   23            10.0           0.245589
#              7           James Justin  Leicester City   26            13.0           0.235346
#              8              Emil Holm         Bologna   24             8.0           0.166424
#              9           Kelvin Amian          Nantes   26             2.5           0.111400
#             10  Ignace Van Der Brempt            Como   22             4.0           0.110176
#             11          Pedro Pereira           Monza   26             1.5           0.099555
#             12 Ainsley Maitland-Niles            Lyon   26            12.0           0.076696
#             13          Nahuel Molina Atlético Madrid   26            20.0           0.065740
#             14           Jon Aramburu   Real Sociedad   22            15.0           0.054509
#             15        Antoine Hainaut           Parma   22             1.0           0.051801
#
# ================================================================================
# REPLACEMENT VALIDATION
# ================================================================================
# ✓ Santiago Mouriño encontrado en ambos pools
#   Rank pool completo: 7
#   Rank pool filtrado: 3/45
#   Similitud: 0.4599
#   Age: 22 | Market value: 3.0M€
#
#   Status: VALIDADO

# %%
from tfm.helpers.viz_helpers import plot_top10_ranking

# Preparar pool filtrado completo para viz
pool_viz = pool_filtrado_completo.copy()

# Eliminar rank original del PCA (viene de all_scores)
if 'rank' in pool_viz.columns:
    pool_viz = pool_viz.drop(columns=['rank'])

# Renombrar rank_filtrado a rank para que la viz lo use
pool_viz = pool_viz.rename(columns={'rank_filtrado': 'rank'})

# Quitar age/market_value para que plot_top10_ranking los añada
pool_viz = pool_viz.drop(columns=['age', 'market_value_m'])

# Preparar result para viz
result_viable = result.copy()
result_viable['similar_players'] = pool_viz

# Override replacement_info con rank filtrado
if replacement_id in pool_filtrado_completo['unique_player_id'].values:
    mourino_row = pool_filtrado_completo[pool_filtrado_completo['unique_player_id'] == replacement_id].iloc[0]
    result_viable['replacement_info'] = {
        'player_name': mourino_row['player_name'],
        'unique_player_id': replacement_id,
        'team': mourino_row['team'],
        'league': mourino_row['league'],
        'season': mourino_row['season'],
        'rank': int(mourino_row['rank_filtrado']),
        'cosine_similarity': float(mourino_row['cosine_similarity'])
    }

output_path = plot_top10_ranking(
    result=result_viable,
    df_data=full_df,
    save_path='foyth_mourino_top10_ranking.png',
    target_face_path='/home/jaime/FD/data/blog/caras/tfm/foyth.png',
    highlight_target=True,
    dpi=300
)

print(f"Visualización: {output_path}")

from IPython.display import Image, display
display(Image(filename=output_path))
# Out:
# Visualización: /home/jaime/FD/data/tfm/teams/villarreal/foyth_mourino_top10_ranking.png

# %%
# PCA Information
pca_info = result['pca_info']

print("\nINFORMACIÓN PCA")
print("="*80)
print(f"Dimensiones originales: {pca_info['original_dimensions']}")
print(f"Componentes retenidos: {pca_info['n_components']}")
print(f"Varianza explicada: {pca_info['explained_variance_ratio']:.1%}")
print(f"Ratio de compresión: {pca_info['compression_ratio']:.1%}")
print("\nVarianza por componente (top-5):")
for i, var in enumerate(pca_info['top_5_components_variance'], 1):
    print(f"  PC{i}: {var:.1%}")
# Out:
# INFORMACIÓN PCA
# ================================================================================
# Dimensiones originales: 170
# Componentes retenidos: 23
# Varianza explicada: 85.5%
# Ratio de compresión: 13.5%
#
# Varianza por componente (top-5):
#   PC1: 18.1%
#   PC2: 12.6%
#   PC3: 8.3%
#   PC4: 6.9%
#   PC5: 5.5%

# %%
# Similarity Score Distribution
dist = result['score_distribution']

print("\nDISTRIBUCIÓN DE SIMILITUDES")
print("="*80)
print(f"Mínimo:   {dist['min']:.4f}")
print(f"Q5:       {dist['q5']:.4f}")
print(f"Q25:      {dist['q25']:.4f}")
print(f"Mediana:  {dist['median']:.4f}")
print(f"Q75:      {dist['q75']:.4f}")
print(f"Q95:      {dist['q95']:.4f}")
print(f"Máximo:   {dist['max']:.4f}")
print(f"Media:    {dist['mean']:.4f}")
print(f"Desv.Est: {dist['std']:.4f}")
# Out:
# DISTRIBUCIÓN DE SIMILITUDES
# ================================================================================
# Mínimo:   -0.5194
# Q5:       -0.4024
# Q25:      -0.1666
# Mediana:  -0.0083
# Q75:      0.1772
# Q95:      0.4650
# Máximo:   0.7442
# Media:    0.0149
# Desv.Est: 0.2713
