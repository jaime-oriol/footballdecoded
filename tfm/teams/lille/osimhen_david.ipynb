# %% [markdown]
# # Victor Osimhen vs Jonathan David - PCA Similarity Analysis
# ## Lille OSC - Delantero Centro
#
# **Context:**
# - Victor Osimhen: Fichado por Lille (verano 19/20, 22.5M€) → vendido Napoli 79M€
# - Jonathan David: Fichado por Lille como reemplazo desde Gent (20/21, 27M€ Liga Belga) → agente libre 2025
# - Position: ST (Striker)
# - Analysis: PCA-based similarity algorithm to validate David as Osimhen replacement
# - **Data analyzed: Season 19/20** (Osimhen: Lille 2287 min, David: Gent 2095 min)
#
# **Metodología:**
# - **Pool PCA estandarizado**: ST, 1000+ min, max 30 años (SIN filtros económicos)
# - **Combina Big 5 + extras (Liga Belga)** para incluir a David en Gent
# - **Ventaja**: PCA independiente de filtros económicos arbitrarios → evita cherry-picking
# - **Filtros post-PCA**: Se aplican DESPUÉS para mostrar opciones viables (≤40M€, ≤26 años)

# %%
import pandas as pd
import numpy as np
import sys
import os

# Subir tres niveles desde tfm/teams/lille/ hasta data/
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..')))

from database.connection import get_db_manager
from tfm.helpers.query_helpers import query_player_pool, add_exogenous_player
from tfm.helpers.algorithms import find_similar_players_cosine

import warnings
warnings.filterwarnings('ignore')

# %%
# Pool PCA estandarizado (SIN filtros económicos)
# Combinar Big 5 + Liga Belga para incluir a David en Gent
big5_leagues = ['ENG-Premier League', 'ESP-La Liga', 'ITA-Serie A', 'GER-Bundesliga', 'FRA-Ligue 1']
extra_leagues = ['BEL-Pro League']  # David jugaba en Gent (Bélgica)

all_leagues = big5_leagues + extra_leagues

pools = []
for league in all_leagues:
    try:
        # Big 5 en domestic, Belga en extras
        table_type = 'domestic' if league in big5_leagues else 'extras'
        
        pool = query_player_pool(
            league=league,
            season='1920',
            positions=['ST'],
            min_minutes=1000,
            max_age=30,
            table_type=table_type
        )
        pools.append(pool)
        print(f"{league}: {len(pool)} jugadores ({table_type})")
    except Exception as e:
        print(f"Error en {league}: {e}")

pool_df = pd.concat(pools, ignore_index=True)

print(f"\nPool PCA (estandarizado): {len(pool_df)} jugadores")
print(f"\nDistribución por liga:")
print(pool_df['league'].value_counts())
# Out:
# 2026-01-12 13:01:28,004 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-12 13:01:28,313 - database.connection - INFO - Database connection successful
# 2026-01-12 13:01:28,423 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-12 13:01:28,459 - database.connection - INFO - Database connection successful
# 2026-01-12 13:01:28,522 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-12 13:01:28,554 - database.connection - INFO - Database connection successful
# 2026-01-12 13:01:28,611 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# ENG-Premier League: 29 jugadores (domestic)
# ESP-La Liga: 30 jugadores (domestic)
# ITA-Serie A: 28 jugadores (domestic)
# 2026-01-12 13:01:28,648 - database.connection - INFO - Database connection successful
# 2026-01-12 13:01:28,698 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-12 13:01:28,737 - database.connection - INFO - Database connection successful
# 2026-01-12 13:01:28,795 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-12 13:01:28,826 - database.connection - INFO - Database connection successful
# GER-Bundesliga: 34 jugadores (domestic)
# FRA-Ligue 1: 25 jugadores (domestic)
# BEL-Pro League: 19 jugadores (extras)
#
# Pool PCA (estandarizado): 165 jugadores
#
# Distribución por liga:
# league
# GER-Bundesliga        34
# ESP-La Liga           30
# ENG-Premier League    29
# ITA-Serie A           28
# FRA-Ligue 1           25
# BEL-Pro League        19
# Name: count, dtype: int64

# %%
# Add Osimhen as exogenous player (target)
full_df = add_exogenous_player(
    pool_df=pool_df,
    player_name='Victor Osimhen',
    league='FRA-Ligue 1',
    season='1920',
    team='Lille',
    table_type='domestic'
)

print(f"DataFrame con Target: {len(full_df)} jugadores")
# Out:
# 2026-01-12 13:01:28,936 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2026-01-12 13:01:28,976 - database.connection - INFO - Database connection successful
# Added exogenous player: Victor Osimhen (Lille, FRA-Ligue 1 1920)
# Total players in DataFrame: 166
# DataFrame con Target: 166 jugadores

# %%
def extract_metrics(df, col_name):
    result = pd.DataFrame(index=df.index)
    all_keys = set()
    for _, row in df.iterrows():
        if isinstance(row[col_name], dict):
            all_keys.update(row[col_name].keys())
    
    for key in all_keys:
        values = []
        for _, row in df.iterrows():
            if isinstance(row[col_name], dict) and key in row[col_name]:
                raw_value = row[col_name][key]
                converted_value = _convert_to_float(raw_value)
                values.append(converted_value)
            else:
                values.append(np.nan)
        
        valid_count = pd.Series(values).notna().sum()
        if valid_count >= 5:
            result[key] = values
    
    return result

def _convert_to_float(value):
    if isinstance(value, (int, float)):
        return float(value)
    if value is None or pd.isna(value):
        return np.nan
    if isinstance(value, str):
        if value.strip() == '' or value.lower().strip() in ['nan', 'none', 'null', '-']:
            return np.nan
        try:
            return float(value)
        except (ValueError, TypeError):
            return np.nan
    return np.nan

fbref_nums = extract_metrics(full_df, 'fbref_metrics')
understat_nums = extract_metrics(full_df, 'understat_metrics')
transfermarkt_nums = extract_metrics(full_df, 'transfermarkt_metrics')

print(f"FBref: {fbref_nums.shape[1]} métricas")
print(f"Understat: {understat_nums.shape[1]} métricas")
print(f"Transfermarkt: {transfermarkt_nums.shape[1]} campos")
# Out:
# FBref: 185 métricas
# Understat: 10 métricas
# Transfermarkt: 2 campos

# %%
exclude_normalization = {
    'minutes_played', 'age', 'birth_year', 'games_started', 'minutes_per_game',
    'minutes_per_start', 'games', 'games_subs', 'unused_sub', 'points_per_game',
    'on_goals_for', 'on_goals_against', 'plus_minus', 'plus_minus_per90',
    'plus_minus_wowy', 'on_xg_for', 'on_xg_against', 'xg_plus_minus',
    'xg_plus_minus_per90', 'xg_plus_minus_wowy', 'Touches_Touches'
}

fbref_per100 = fbref_nums.loc[:, ~fbref_nums.columns.isin(exclude_normalization)]
fbref_per100 = (fbref_per100.div(fbref_nums['Touches_Touches'], axis=0) * 100).round(3)
fbref_per100.columns = [f'{col}_per100touches' for col in fbref_per100.columns]

understat_per100 = understat_nums.loc[:, ~understat_nums.columns.isin(exclude_normalization)]
understat_per100 = (understat_per100.div(fbref_nums['Touches_Touches'], axis=0) * 100).round(3)
understat_per100.columns = [f'{col}_per100touches' for col in understat_per100.columns]

print(f"Per100touches FBref: {fbref_per100.shape[1]} columnas")
print(f"Per100touches Understat: {understat_per100.shape[1]} columnas")
# Out:
# Per100touches FBref: 183 columnas
# Per100touches Understat: 10 columnas

# %%
base_cols = ['unique_player_id', 'player_name', 'team', 'league', 'season', 'position', 'age']

df_final = pd.concat([
    full_df[base_cols],
    fbref_nums,
    understat_nums,
    transfermarkt_nums,
    fbref_per100,
    understat_per100
], axis=1)

print(f"DataFrame final: {df_final.shape[0]} jugadores × {df_final.shape[1]} columnas")
# Out:
# DataFrame final: 166 jugadores × 397 columnas

# %%
# Identify target (Osimhen) and replacement (David)
target = df_final[df_final['player_name'].str.contains('Osimhen', case=False, na=False)]
replacement = df_final[df_final['player_name'].str.contains('Jonathan David', case=False, na=False)]

if len(target) == 0:
    raise ValueError("Target no encontrado")
if len(replacement) == 0:
    raise ValueError("Replacement no encontrado")

target_id = target.iloc[0]['unique_player_id']
replacement_id = replacement.iloc[0]['unique_player_id']

print(f"Target: {target.iloc[0]['player_name']} ({target.iloc[0]['team']})")
print(f"  ID: {target_id}")
print(f"\nReemplazo: {replacement.iloc[0]['player_name']} ({replacement.iloc[0]['team']})")
print(f"  ID: {replacement_id}")
# Out:
# Target: Victor Osimhen (Lille)
#   ID: 33e635289747ff6e
#
# Reemplazo: Jonathan David (Gent)
#   ID: 5988b6b8ef63203f

# %%
# Run PCA similarity algorithm
result = find_similar_players_cosine(
    df=df_final,
    target_player_id=target_id,
    n_similar=30,
    pca_variance=0.85,
    replacement_id=replacement_id,
    robust_scaling=False,
    return_all_scores=True
)
# Out:
# Target: Victor Osimhen (Lille, FRA-Ligue 1)
# Features: 170 (per 100 touches, excl. GK)
# Jugadores: 166 (eliminados 0 con NaNs CORE)
# PCA: 29 componentes (varianza: 85.7%)
# Reducción: 170 → 29 dimensiones
# Top-30 encontrados
# Rango similitud: [0.2728, 0.6426]

# %%
# Filtrar resultados por restricciones de mercado (post-PCA)
MAX_VALUE = 40  # Millones €
MAX_AGE_FILTER = 24  # Edad máxima para filtrado económico

# Extraer datos del full_df
def get_market_value(player_id):
    player_row = full_df[full_df['unique_player_id'] == player_id]
    if len(player_row) == 0:
        return None
    tm_metrics = player_row.iloc[0].get('transfermarkt_metrics')
    if isinstance(tm_metrics, dict):
        val = tm_metrics.get('transfermarkt_market_value_eur')
        return float(val) / 1_000_000 if val else None
    return None

def get_age(player_id):
    player_row = full_df[full_df['unique_player_id'] == player_id]
    if len(player_row) == 0:
        return None
    return player_row.iloc[0].get('age')

# Obtener ALL scores (no solo top-30)
all_scores_df = result['all_scores'].copy()
all_scores_df['market_value_m'] = all_scores_df['unique_player_id'].apply(get_market_value)
all_scores_df['age'] = all_scores_df['unique_player_id'].apply(get_age)

# Filtrar TODO el pool por edad/valor de mercado
pool_filtrado_completo = all_scores_df[
    (all_scores_df['market_value_m'] <= MAX_VALUE) &
    (all_scores_df['age'] <= MAX_AGE_FILTER)
].copy()

# Re-rankear pool filtrado completo
pool_filtrado_completo = pool_filtrado_completo.sort_values('cosine_similarity', ascending=False).reset_index(drop=True)
pool_filtrado_completo['rank_filtrado'] = range(1, len(pool_filtrado_completo) + 1)

# Top-30 del pool completo (para display)
similar_df = result['similar_players'].copy()
similar_df['market_value_m'] = similar_df['unique_player_id'].apply(get_market_value)
similar_df['age'] = similar_df['unique_player_id'].apply(get_age)

print("TOP 30 - Pool Completo")
print("="*80)
print(similar_df[['rank', 'player_name', 'team', 'age', 'market_value_m', 'cosine_similarity']].head(30).to_string(index=False))

# Top-15 del pool filtrado (para display)
viable_df = pool_filtrado_completo.head(15).copy()

print(f"\n\nTOP 15 - Pool Filtrado (≤{MAX_VALUE}M€, ≤{MAX_AGE_FILTER} años)")
print("="*80)
print(f"Total jugadores en pool filtrado: {len(pool_filtrado_completo)}")
print("\n" + viable_df[['rank_filtrado', 'player_name', 'team', 'age', 'market_value_m', 'cosine_similarity']].head(15).to_string(index=False))

# REPLACEMENT VALIDATION
print("\n" + "="*80)
print("REPLACEMENT VALIDATION")
print("="*80)

replacement_name = replacement.iloc[0]['player_name'] if len(replacement) > 0 else "Replacement"

if replacement_id in pool_filtrado_completo['unique_player_id'].values:
    david_row_filtered = pool_filtrado_completo[pool_filtrado_completo['unique_player_id'] == replacement_id].iloc[0]

    # Info del pool completo
    repl_info = result.get('replacement_info')
    rank_completo = repl_info['rank'] if repl_info else None

    print(f"✓ {replacement_name} encontrado en ambos pools")
    print(f"  Rank pool completo: {rank_completo}")
    print(f"  Rank pool filtrado: {david_row_filtered['rank_filtrado']}/{len(pool_filtrado_completo)}")
    print(f"  Similitud: {david_row_filtered['cosine_similarity']:.4f}")
    print(f"  Age: {david_row_filtered['age']} | Market value: {david_row_filtered['market_value_m']:.1f}M€")
    print(f"\n  Status: VALIDADO" if david_row_filtered['rank_filtrado'] <= 10 else f"  Status: Rank {david_row_filtered['rank_filtrado']}")
else:
    repl_info = result.get('replacement_info')
    if repl_info and repl_info.get('rank'):
        rank_completo = repl_info['rank']
        age = get_age(replacement_id)
        market_value = get_market_value(replacement_id)

        print(f"✓ {replacement_name} en pool completo, NO en pool filtrado")
        print(f"  Rank pool completo: {rank_completo}")
        print(f"  Age: {age} | Market value: {market_value:.1f}M€")

        reasons = []
        if market_value and market_value > MAX_VALUE:
            reasons.append(f"valor {market_value:.1f}M€ > {MAX_VALUE}M€")
        if age and age > MAX_AGE_FILTER:
            reasons.append(f"edad {age} > {MAX_AGE_FILTER}")
        print(f"  Excluido: {', '.join(reasons)}")
    else:
        print(f"✗ {replacement_name} NO encontrado en pool PCA")
# Out:
# TOP 30 - Pool Completo
# ================================================================================
#  rank           player_name            team  age  market_value_m  cosine_similarity
#     1            Chris Wood         Burnley   27            14.5           0.642624
#     2        Moussa Dembélé            Lyon   23            40.0           0.572306
#     3         Tammy Abraham         Chelsea   21            40.0           0.535902
#     4         Álvaro Morata Atlético Madrid   26            36.0           0.534303
#     5      Kalifa Coulibaly          Nantes   27             4.0           0.528058
#     6         Ashley Barnes         Burnley   29             8.0           0.501831
#     7          Habib Diallo            Metz   24            12.0           0.498278
#     8 Dominic Calvert-Lewin         Everton   22            24.0           0.487923
#     9      Giovanni Simeone        Cagliari   24            13.5           0.486900
#    10        Kasper Dolberg            Nice   21            16.0           0.485629
#    11      Lautaro Martínez           Inter   21            64.0           0.442675
#    12     Samuel Di Carmine   Hellas Verona   30             1.4           0.439438
#    13         Callum Wilson     Bournemouth   27            24.0           0.414885
#    14          Jhon Córdoba            Köln   26            12.0           0.404969
#    15          Mauro Icardi       Paris S-G   26            60.0           0.390549
#    16 Florian Niederlechner        Augsburg   28            10.0           0.373793
#    17     Gianluca Lapadula           Lecce   29             4.8           0.361898
#    18           Boulaye Dia           Reims   22             4.5           0.352653
#    19     Youssef En-Nesyri         Leganés   22            12.0           0.348490
#    20           Teemu Pukki    Norwich City   29             8.0           0.344873
#    21           Simone Zaza          Torino   28             7.0           0.337546
#    22         Patrik Schick      RB Leipzig   23            25.0           0.335784
#    23          Duván Zapata        Atalanta   28            36.0           0.311968
#    24  Jean-Philippe Mateta        Mainz 05   22            17.5           0.309137
#    25      Krzysztof Piątek           Milan   24            21.5           0.306686
#    26     Gonçalo Paciência  Eint Frankfurt   24            12.0           0.303235
#    27        Erling Haaland        Dortmund   19            72.0           0.297845
#    28          Ante Budimir        Mallorca   28            15.0           0.282215
#    29    Robert Lewandowski   Bayern Munich   30            56.0           0.273951
#    30         Wesley Moraes     Aston Villa   22            24.0           0.272808
#
#
# TOP 15 - Pool Filtrado (≤40M€, ≤24 años)
# ================================================================================
# Total jugadores en pool filtrado: 58
#
#  rank_filtrado           player_name           team  age  market_value_m  cosine_similarity
#              1        Moussa Dembélé           Lyon   23            40.0           0.572306
#              2         Tammy Abraham        Chelsea   21            40.0           0.535902
#              3          Habib Diallo           Metz   24            12.0           0.498278
#              4 Dominic Calvert-Lewin        Everton   22            24.0           0.487923
#              5      Giovanni Simeone       Cagliari   24            13.5           0.486900
#              6        Kasper Dolberg           Nice   21            16.0           0.485629
#              7           Boulaye Dia          Reims   22             4.5           0.352653
#              8     Youssef En-Nesyri        Leganés   22            12.0           0.348490
#              9         Patrik Schick     RB Leipzig   23            25.0           0.335784
#             10  Jean-Philippe Mateta       Mainz 05   22            17.5           0.309137
#             11      Krzysztof Piątek          Milan   24            21.5           0.306686
#             12     Gonçalo Paciência Eint Frankfurt   24            12.0           0.303235
#             13         Wesley Moraes    Aston Villa   22            24.0           0.272808
#             14           Lys Mousset  Sheffield Utd   23             9.5           0.228400
#             15          Lebo Mothiba     Strasbourg   23             4.0           0.216711
#
# ================================================================================
# REPLACEMENT VALIDATION
# ================================================================================
# ✓ Jonathan David encontrado en ambos pools
#   Rank pool completo: 148
#   Rank pool filtrado: 55/58
#   Similitud: -0.4400
#   Age: 19 | Market value: 22.5M€
#   Status: Rank 55

# %%
from tfm.helpers.viz_helpers import plot_top10_ranking

# Preparar pool filtrado completo para viz
pool_viz = pool_filtrado_completo.copy()

# Eliminar rank original del PCA (viene de all_scores)
if 'rank' in pool_viz.columns:
    pool_viz = pool_viz.drop(columns=['rank'])

# Renombrar rank_filtrado a rank para que la viz lo use
pool_viz = pool_viz.rename(columns={'rank_filtrado': 'rank'})

# Quitar age/market_value para que plot_top10_ranking los añada
pool_viz = pool_viz.drop(columns=['age', 'market_value_m'])

# Preparar result para viz
result_viable = result.copy()
result_viable['similar_players'] = pool_viz

# Override replacement_info con rank filtrado
if replacement_id in pool_filtrado_completo['unique_player_id'].values:
    david_row = pool_filtrado_completo[pool_filtrado_completo['unique_player_id'] == replacement_id].iloc[0]
    result_viable['replacement_info'] = {
        'player_name': david_row['player_name'],
        'unique_player_id': replacement_id,
        'team': david_row['team'],
        'league': david_row['league'],
        'season': david_row['season'],
        'rank': int(david_row['rank_filtrado']),
        'cosine_similarity': float(david_row['cosine_similarity'])
    }

output_path = plot_top10_ranking(
    result=result_viable,
    df_data=full_df,
    save_path='osimhen_david_top10_ranking.png',
    target_face_path='/home/jaime/FD/data/blog/caras/tfm/osimhen.png',
    highlight_target=True,
    dpi=300
)

print(f"Visualización: {output_path}")

from IPython.display import Image, display
display(Image(filename=output_path))
# Out:
# Visualización: /home/jaime/FD/data/tfm/teams/lille/osimhen_david_top10_ranking.png

# %%
# PCA Information
pca_info = result['pca_info']

print("\nINFORMACIÓN PCA")
print("="*80)
print(f"Dimensiones originales: {pca_info['original_dimensions']}")
print(f"Componentes retenidos: {pca_info['n_components']}")
print(f"Varianza explicada: {pca_info['explained_variance_ratio']:.1%}")
print(f"Ratio de compresión: {pca_info['compression_ratio']:.1%}")
print("\nVarianza por componente (top-5):")
for i, var in enumerate(pca_info['top_5_components_variance'], 1):
    print(f"  PC{i}: {var:.1%}")
# Out:
# INFORMACIÓN PCA
# ================================================================================
# Dimensiones originales: 170
# Componentes retenidos: 29
# Varianza explicada: 85.7%
# Ratio de compresión: 17.1%
#
# Varianza por componente (top-5):
#   PC1: 16.5%
#   PC2: 10.9%
#   PC3: 8.2%
#   PC4: 6.5%
#   PC5: 5.6%

# %%
# Similarity Score Distribution
dist = result['score_distribution']

print("\nDISTRIBUCIÓN DE SIMILITUDES")
print("="*80)
print(f"Mínimo:   {dist['min']:.4f}")
print(f"Q5:       {dist['q5']:.4f}")
print(f"Q25:      {dist['q25']:.4f}")
print(f"Mediana:  {dist['median']:.4f}")
print(f"Q75:      {dist['q75']:.4f}")
print(f"Q95:      {dist['q95']:.4f}")
print(f"Máximo:   {dist['max']:.4f}")
print(f"Media:    {dist['mean']:.4f}")
print(f"Desv.Est: {dist['std']:.4f}")
# Out:
# DISTRIBUCIÓN DE SIMILITUDES
# ================================================================================
# Mínimo:   -0.7530
# Q5:       -0.5204
# Q25:      -0.2347
# Mediana:  0.0022
# Q75:      0.1919
# Q95:      0.4867
# Máximo:   0.6426
# Media:    -0.0210
# Desv.Est: 0.2981
