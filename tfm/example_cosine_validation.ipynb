# %%
import pandas as pd
import numpy as np
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from database.connection import get_db_manager
from tfm.query_helpers import query_player_pool, add_exogenous_player
from tfm.algorithms import find_similar_players_cosine

import warnings
warnings.filterwarnings('ignore')

# %%
big5_leagues = ['ENG-Premier League', 'ESP-La Liga', 'ITA-Serie A', 'GER-Bundesliga', 'FRA-Ligue 1']

pools = []
for league in big5_leagues:
    try:
        pool = query_player_pool(
            league=league,
            season='2324',
            positions=['CB'],
            max_market_value=15_000_000,
            min_minutes=1250,
            max_age=26
        )
        pools.append(pool)
        print(f"{league}: {len(pool)} jugadores")
    except Exception as e:
        print(f"Error en {league}: {e}")

pool_df = pd.concat(pools, ignore_index=True)

print(f"\nPool total: {len(pool_df)} jugadores")
print(f"\nDistribución por liga:")
print(pool_df['league'].value_counts())
# Out:
# 2025-12-05 15:48:35,250 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2025-12-05 15:48:35,371 - database.connection - INFO - Database connection successful
# 2025-12-05 15:48:35,389 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2025-12-05 15:48:35,414 - database.connection - INFO - Database connection successful
# 2025-12-05 15:48:35,431 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2025-12-05 15:48:35,455 - database.connection - INFO - Database connection successful
# 2025-12-05 15:48:35,468 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2025-12-05 15:48:35,495 - database.connection - INFO - Database connection successful
# 2025-12-05 15:48:35,507 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2025-12-05 15:48:35,530 - database.connection - INFO - Database connection successful
# ENG-Premier League: 9 jugadores
# ESP-La Liga: 22 jugadores
# WARNING: No players found with filters:
#   League: ITA-Serie A, Season: 2324
#   Positions: ['CB']
#   Max market value: 15,000,000 EUR
#   Min minutes: 1250
#   Max age: 26
# ITA-Serie A: 0 jugadores
# WARNING: No players found with filters:
#   League: GER-Bundesliga, Season: 2324
#   Positions: ['CB']
#   Max market value: 15,000,000 EUR
#   Min minutes: 1250
#   Max age: 26
# GER-Bundesliga: 0 jugadores
# FRA-Ligue 1: 25 jugadores
#
# Pool total: 56 jugadores
#
# Distribución por liga:
# league
# FRA-Ligue 1           25
# ESP-La Liga           22
# ENG-Premier League     9
# Name: count, dtype: int64

# %%
full_df = add_exogenous_player(
    pool_df=pool_df,
    player_name='Pau Torres',
    league='ESP-La Liga',
    season='2223',
    team='Villarreal'
)

print(f"DataFrame con Target: {len(full_df)} jugadores")
# Out:
# 2025-12-05 15:48:35,568 - database.connection - INFO - Connecting to database: localhost:5432/footballdecoded_dev
# 2025-12-05 15:48:35,599 - database.connection - INFO - Database connection successful
# Added exogenous player: Pau Torres (Villarreal, ESP-La Liga 2223)
# Total players in DataFrame: 57
# DataFrame con Target: 57 jugadores

# %%
def extract_metrics(df, col_name):
    result = pd.DataFrame(index=df.index)
    all_keys = set()
    for _, row in df.iterrows():
        if isinstance(row[col_name], dict):
            all_keys.update(row[col_name].keys())
    
    for key in all_keys:
        values = []
        for _, row in df.iterrows():
            if isinstance(row[col_name], dict) and key in row[col_name]:
                raw_value = row[col_name][key]
                converted_value = _convert_to_float(raw_value)
                values.append(converted_value)
            else:
                values.append(np.nan)
        
        valid_count = pd.Series(values).notna().sum()
        if valid_count >= 5:
            result[key] = values
    
    return result

def _convert_to_float(value):
    if isinstance(value, (int, float)):
        return float(value)
    if value is None or pd.isna(value):
        return np.nan
    if isinstance(value, str):
        if value.strip() == '' or value.lower().strip() in ['nan', 'none', 'null', '-']:
            return np.nan
        try:
            return float(value)
        except (ValueError, TypeError):
            return np.nan
    return np.nan

fbref_nums = extract_metrics(full_df, 'fbref_metrics')
understat_nums = extract_metrics(full_df, 'understat_metrics')
transfermarkt_nums = extract_metrics(full_df, 'transfermarkt_metrics')

print(f"FBref: {fbref_nums.shape[1]} métricas")
print(f"Understat: {understat_nums.shape[1]} métricas")
print(f"Transfermarkt: {transfermarkt_nums.shape[1]} campos")
# Out:
# FBref: 145 métricas
# Understat: 10 métricas
# Transfermarkt: 2 campos

# %%
exclude_per90 = {
    'minutes_played', 'age', 'birth_year', 'games_started', 'minutes_per_game',
    'minutes_per_start', 'games', 'games_subs', 'unused_sub', 'points_per_game',
    'on_goals_for', 'on_goals_against', 'plus_minus', 'plus_minus_per90',
    'plus_minus_wowy', 'on_xg_for', 'on_xg_against', 'xg_plus_minus',
    'xg_plus_minus_per90', 'xg_plus_minus_wowy'
}

fbref_per90 = fbref_nums.loc[:, ~fbref_nums.columns.isin(exclude_per90)]
fbref_per90 = (fbref_per90.div(fbref_nums['minutes_played'], axis=0) * 90).round(3)
fbref_per90.columns = [f'{col}_per90' for col in fbref_per90.columns]

understat_per90 = understat_nums.loc[:, ~understat_nums.columns.isin(exclude_per90)]
understat_per90 = (understat_per90.div(fbref_nums['minutes_played'], axis=0) * 90).round(3)
understat_per90.columns = [f'{col}_per90' for col in understat_per90.columns]

print(f"Per90 FBref: {fbref_per90.shape[1]} columnas")
print(f"Per90 Understat: {understat_per90.shape[1]} columnas")
# Out:
# Per90 FBref: 144 columnas
# Per90 Understat: 10 columnas

# %%
base_cols = ['unique_player_id', 'player_name', 'team', 'league', 'season', 'position']

df_final = pd.concat([
    full_df[base_cols],
    fbref_nums,
    understat_nums,
    transfermarkt_nums,
    fbref_per90,
    understat_per90
], axis=1)

print(f"DataFrame final: {df_final.shape[0]} jugadores × {df_final.shape[1]} columnas")
# Out:
# DataFrame final: 57 jugadores × 317 columnas

# %%
target = df_final[df_final['player_name'].str.contains('Pau Torres', case=False, na=False)]
replacement = df_final[df_final['player_name'].str.contains('Costa', case=False, na=False)]

if len(target) == 0:
    raise ValueError("Taget no encontrado")
if len(replacement) == 0:
    raise ValueError("Replacement no encontrado")

target_id = target.iloc[0]['unique_player_id']
replacement_id = replacement.iloc[0]['unique_player_id']

print(f"Target: {target.iloc[0]['player_name']} ({target.iloc[0]['team']})")
print(f"  ID: {target_id}")
print(f"\nReemplazo: {replacement.iloc[0]['player_name']} ({replacement.iloc[0]['team']})")
print(f"  ID: {replacement_id}")
# Out:
# Target: Pau Torres (Villarreal)
#   ID: 7038310ad2ae51db
#
# Reemplazo: Logan Costa (Toulouse)
#   ID: 3b445a031f685465

# %%
result = find_similar_players_cosine(
    df=df_final,
    target_player_id=target_id,
    n_similar=30,
    pca_variance=0.85,
    replacement_id=replacement_id,
    robust_scaling=False
)
# Out:
# Target: Pau Torres (Villarreal, ESP-La Liga)
# Features: 154 (solo _per90, excl. GK)
# Jugadores: 57 (eliminados 0 con NaNs CORE)
# PCA: 20 componentes (varianza: 85.1%)
# Reducción: 154 → 20 dimensiones
# Top-30 encontrados
# Rango similitud: [-0.0290, 0.6176]

# %%
top30 = result['similar_players'][[
    'rank', 'player_name', 'team', 'league',
    'cosine_similarity', 'validation_status'
]].copy()

top30['cosine_similarity'] = top30['cosine_similarity'].round(4)

print("TOP-30 SIMILARES A BAENA")
print("="*80)
print(top30.to_string(index=False))
# Out:
# TOP-30 SIMILARES A BAENA
# ================================================================================
#  rank           player_name            team             league  cosine_similarity validation_status
#     1           Logan Costa        Toulouse        FRA-Ligue 1             0.6176          VALIDADO
#     2          Warmed Omari          Rennes        FRA-Ligue 1             0.5998          VALIDADO
#     3 Youssouf Ndayishimiye            Nice        FRA-Ligue 1             0.5788          VALIDADO
#     4          Lucas Perrin      Strasbourg        FRA-Ligue 1             0.5762          VALIDADO
#     5      Emmanuel Agbadou           Reims        FRA-Ligue 1             0.5576          VALIDADO
#     6       Lilian Brassier           Brest        FRA-Ligue 1             0.4992          VALIDADO
#     7            Unai Núñez      Celta Vigo        ESP-La Liga             0.4582          VALIDADO
#     8          Joseph Okumu           Reims        FRA-Ligue 1             0.4100          VALIDADO
#     9           Mika Mármol      Las Palmas        ESP-La Liga             0.2947          VALIDADO
#    10         Omar Alderete          Getafe        ESP-La Liga             0.2271          VALIDADO
#    11       Duje Ćaleta-Car            Lyon        FRA-Ligue 1             0.2072           PARCIAL
#    12          Thilo Kehrer          Monaco        FRA-Ligue 1             0.1972           PARCIAL
#    13           Jon Pacheco   Real Sociedad        ESP-La Liga             0.1555           PARCIAL
#    14       Montassar Talbi         Lorient        FRA-Ligue 1             0.1347           PARCIAL
#    15          Andy Pelmard   Clermont Foot        FRA-Ligue 1             0.1173           PARCIAL
#    16      Christopher Wooh          Rennes        FRA-Ligue 1             0.1106           PARCIAL
#    17           Dara O'Shea         Burnley ENG-Premier League             0.0982           PARCIAL
#    18       Arouna Sangante        Le Havre        FRA-Ligue 1             0.0721           PARCIAL
#    19          Abakar Sylla      Strasbourg        FRA-Ligue 1             0.0635           PARCIAL
#    20      Jeanuël Belocian          Rennes        FRA-Ligue 1             0.0427           PARCIAL
#    21        Becir Omeragic     Montpellier        FRA-Ligue 1             0.0236           PARCIAL
#    22             Loïc Bade         Sevilla        ESP-La Liga             0.0210           PARCIAL
#    23     Rasmus Nicolaisen        Toulouse        FRA-Ligue 1             0.0183           PARCIAL
#    24                Danilo Nott'ham Forest ENG-Premier League             0.0143           PARCIAL
#    25       Kristoffer Ajer       Brentford ENG-Premier League             0.0068           PARCIAL
#    26       Ismaël Doukouré      Strasbourg        FRA-Ligue 1             0.0012           PARCIAL
#    27          Víctor Chust           Cádiz        ESP-La Liga            -0.0013           PARCIAL
#    28            Rafa Marín          Alavés        ESP-La Liga            -0.0117           PARCIAL
#    29          Jorge Cuenca      Villarreal        ESP-La Liga            -0.0230           PARCIAL
#    30         Moussa Diarra        Toulouse        FRA-Ligue 1            -0.0290           PARCIAL

# %%
repl_info = result['replacement_info']

print("\n" + "="*80)
print("="*80)
print(f"Jugador: {repl_info['player_name']}")
print(f"Equipo: {repl_info['team']} ({repl_info['league']})")
print(f"Posición en ranking: #{repl_info['rank']}")
print(f"Similitud coseno: {repl_info['cosine_similarity']:.4f}")
print(f"Percentil: {repl_info['similarity_percentile']:.1f}%")
print(f"Status: {repl_info['validation_status']}")
print("="*80)
# Out:
# ================================================================================
# ================================================================================
# Jugador: Logan Costa
# Equipo: Toulouse (FRA-Ligue 1)
# Posición en ranking: #1
# Similitud coseno: 0.6176
# Percentil: 98.2%
# Status: VALIDADO
# ================================================================================

# %%
pca_info = result['pca_info']

print("\nINFORMACIÓN PCA")
print("="*80)
print(f"Dimensiones originales: {pca_info['original_dimensions']}")
print(f"Componentes retenidos: {pca_info['n_components']}")
print(f"Varianza explicada: {pca_info['explained_variance_ratio']:.1%}")
print(f"Ratio de compresión: {pca_info['compression_ratio']:.1%}")
print("\nVarianza por componente (top-5):")
for i, var in enumerate(pca_info['top_5_components_variance'], 1):
    print(f"  PC{i}: {var:.1%}")
# Out:
# INFORMACIÓN PCA
# ================================================================================
# Dimensiones originales: 154
# Componentes retenidos: 20
# Varianza explicada: 85.1%
# Ratio de compresión: 13.0%
#
# Varianza por componente (top-5):
#   PC1: 18.8%
#   PC2: 12.9%
#   PC3: 7.7%
#   PC4: 6.5%
#   PC5: 5.0%

# %%
dist = result['score_distribution']

print("\nDISTRIBUCIÓN DE SIMILITUDES")
print("="*80)
print(f"Mínimo:   {dist['min']:.4f}")
print(f"Q5:       {dist['q5']:.4f}")
print(f"Q25:      {dist['q25']:.4f}")
print(f"Mediana:  {dist['median']:.4f}")
print(f"Q75:      {dist['q75']:.4f}")
print(f"Q95:      {dist['q95']:.4f}")
print(f"Máximo:   {dist['max']:.4f}")
print(f"Media:    {dist['mean']:.4f}")
print(f"Desv.Est: {dist['std']:.4f}")
# Out:
# DISTRIBUCIÓN DE SIMILITUDES
# ================================================================================
# Mínimo:   -0.5531
# Q5:       -0.4795
# Q25:      -0.2381
# Mediana:  -0.0174
# Q75:      0.1217
# Q95:      0.5768
# Máximo:   0.6176
# Media:    -0.0214
# Desv.Est: 0.3084
